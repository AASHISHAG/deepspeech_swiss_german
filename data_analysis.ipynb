# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
with open('out_swiss.txt', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)
    
df['len_ratio']= df['src'].str.len()/df['res'].str.len()

# %%
df.columns
# Out:
# Index(['cer', 'char_distance', 'char_length', 'loss', 'res', 'src',
#        'wav_filename', 'wer', 'word_distance', 'word_length', 'len_ratio'],
#       dtype='object')

# %%
df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length']]
# Out:
#                                            wav_filename  \
# 0     /media/data/LTLab.lan/agarwal/german-speech-co...
# 1     /media/data/LTLab.lan/agarwal/german-speech-co...
# 2     /media/data/LTLab.lan/agarwal/german-speech-co...
# 3     /media/data/LTLab.lan/agarwal/german-speech-co...
# 4     /media/data/LTLab.lan/agarwal/german-speech-co...
# 5     /media/data/LTLab.lan/agarwal/german-speech-co...
# 6     /media/data/LTLab.lan/agarwal/german-speech-co...
# 7     /media/data/LTLab.lan/agarwal/german-speech-co...
# 8     /media/data/LTLab.lan/agarwal/german-speech-co...
# 9     /media/data/LTLab.lan/agarwal/german-speech-co...
# 10    /media/data/LTLab.lan/agarwal/german-speech-co...
# 11    /media/data/LTLab.lan/agarwal/german-speech-co...
# 12    /media/data/LTLab.lan/agarwal/german-speech-co...
# 13    /media/data/LTLab.lan/agarwal/german-speech-co...
# 14    /media/data/LTLab.lan/agarwal/german-speech-co...
# 15    /media/data/LTLab.lan/agarwal/german-speech-co...
# ...

# %%
ax = sns.distplot(df['wer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
df_no_issue = df[df['len_ratio'] < 1.3]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['wer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 5472
# 2535

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.39553925080895147
# 0.2561877242335567
#
# 0.6157376132260195
# 0.46847340358462874

# %% [markdown]
# # New Hyperparameters

# %%
with open('out_swiss_new_hyperparameters.txt', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)

df['len_ratio']= df['src'].str.len()/df['res'].str.len()

# %%
df.columns
# Out:
# Index(['cer', 'char_distance', 'char_length', 'loss', 'res', 'src',
#        'wav_filename', 'wer', 'word_distance', 'word_length', 'len_ratio'],
#       dtype='object')

# %%
df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length']]
# Out:
#                                            wav_filename  \
# 0     /media/data/LTLab.lan/agarwal/german-speech-co...
# 1     /media/data/LTLab.lan/agarwal/german-speech-co...
# 2     /media/data/LTLab.lan/agarwal/german-speech-co...
# 3     /media/data/LTLab.lan/agarwal/german-speech-co...
# 4     /media/data/LTLab.lan/agarwal/german-speech-co...
# 5     /media/data/LTLab.lan/agarwal/german-speech-co...
# 6     /media/data/LTLab.lan/agarwal/german-speech-co...
# 7     /media/data/LTLab.lan/agarwal/german-speech-co...
# 8     /media/data/LTLab.lan/agarwal/german-speech-co...
# 9     /media/data/LTLab.lan/agarwal/german-speech-co...
# 10    /media/data/LTLab.lan/agarwal/german-speech-co...
# 11    /media/data/LTLab.lan/agarwal/german-speech-co...
# 12    /media/data/LTLab.lan/agarwal/german-speech-co...
# 13    /media/data/LTLab.lan/agarwal/german-speech-co...
# 14    /media/data/LTLab.lan/agarwal/german-speech-co...
# 15    /media/data/LTLab.lan/agarwal/german-speech-co...
# ...

# %%
ax = sns.distplot(df['wer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
df_no_issue = df[df['len_ratio'] < 1.3]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['wer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 5472
# 3262

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.3561804414328308
# 0.2696030848140195
#
# 0.5878913819295042
# 0.5001845588563747

# %%
#sns.pairplot(df[['wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length']])

# %%
#myBasicCorr = df.corr()
#sns.heatmap(myBasicCorr, annot = True)
#fig = plt.gcf()  # or by other means, like plt.subplots
#figsize = fig.get_size_inches()
#sns.set(font_scale=3)
#fig.set_size_inches(figsize * 2)  # scale current size by 1.5
