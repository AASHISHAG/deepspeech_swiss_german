# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
with open('in_aishell2_2048.json', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)
    
df['len_ratio']= df['res'].str.len()/df['src'].str.len()

# %%
df.columns
# Out:
# Index(['wav_filename', 'src', 'res', 'loss', 'char_distance', 'char_length',
#        'word_distance', 'word_length', 'cer', 'wer', 'len_ratio'],
#       dtype='object')

# %%
#df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length', 'len_ratio']]

# %%
ax = sns.distplot(df['cer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
df_no_issue = df[df['len_ratio'] > 0.75]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 151296
# 119734

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.30084263608648354
# 0.20111582494073285
#
# 0.6553907571912013
# 0.5645514223194749

# %% [markdown]
# # New Hyperparameters

# %%
with open('in_aishell2_2048.json', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)

df['len_ratio']= df['res'].str.len()/df['src'].str.len()

# %%
df.columns
# Out:
# Index(['wav_filename', 'src', 'res', 'loss', 'char_distance', 'char_length',
#        'word_distance', 'word_length', 'cer', 'wer', 'len_ratio'],
#       dtype='object')

# %%
#df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length']]

# %%
ax = sns.distplot(df['cer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
sns.distplot(df['len_ratio'], color="g", kde_kws={"shade": True}, hist=False, rug=True)

# %%
sns.distplot(df['len_ratio'], bins=20, kde=True, rug=False)

# %%
df_no_issue = df[df['len_ratio'] > 0.75]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 151296
# 119734

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.30084263608648354
# 0.20111582494073285
#
# 0.6553907571912013
# 0.5645514223194749

# %%
df_no_issue = df[df['len_ratio'] > 0.85]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 151296
# 106336

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.30084263608648354
# 0.17704839885771861
#
# 0.6553907571912013
# 0.5096862774601264

# %%
df_no_issue = df[df['len_ratio'] > 0.90]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 151296
# 95755

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.30084263608648354
# 0.16535683391578046
#
# 0.6553907571912013
# 0.45550623988303485

# %%
df_no_issue = df[df['len_ratio'] > 0.95]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 151296
# 85854

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.2979939511103375
# 0.13915155272742144
#
# 0.85546875
# 0.6144494616186176
