# %%
import json
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame()

# %%
with open('t_thchs30.json', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)
    
df['len_ratio']= df['res'].str.len()/df['src'].str.len()

# %%
df.columns
# Out:
# Index(['cer', 'char_distance', 'char_length', 'loss', 'res', 'src',
#        'wav_filename', 'wer', 'word_distance', 'word_length', 'len_ratio'],
#       dtype='object')

# %%
df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length', 'len_ratio']]
# Out:
#                                            wav_filename  \
# 0     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 1     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 3     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 4     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 5     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 6     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 7     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 8     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 9     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 10    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 11    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 12    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 13    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 14    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 15    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 16    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 17    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 18    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 19    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 20    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 21    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 22    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 23    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 24    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 25    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 26    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 27    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 28    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 29    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# ...                                                 ...
# 2402  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2403  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2404  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2405  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2406  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2407  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2408  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2409  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2410  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2411  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2412  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2413  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2414  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2415  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2416  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2417  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2418  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2419  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2420  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2421  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2422  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2423  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2424  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2425  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2426  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2427  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2428  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2429  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2430  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2431  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
#
#                                               src  \
# 0                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 1                   然而我们应该有却还没有一个严密完整的外来人口管理条例和机构
# 2                         除中文外还将制作英日等外文版软盘以方便海外用户
# 3                         除中文外还将制作英日等外文版软盘以方便海外用户
# 4                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 5                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 6                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 7                 花卉的产销网络从近郊扩展到省内从省内扩展到省外从省外扩展到国外
# 8                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 9                   然而我们应该有却还没有一个严密完整的外来人口管理条例和机构
# 10                    你要我有了爱情才结婚可是我就没有哇也找不到哇叫我怎么办
# 11        其中匈牙利为三十五亿美元捷克为二十五亿美元波兰为二十五亿美元俄罗斯达二十亿美元
# 12                      因此笼统地说女人怎样怎样比说男人怎样怎样要有把握些
# 13               为了使生育按计划进行就要运用医学科学的原理采取各种避孕节育的措施
# 14                  全国煤炭订货会纪律严明不受外界干扰因而也成为一个高效率的会
# 15                        除中文外还将制作英日等外文版软盘以方便海外用户
# 16              收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人
# 17                    招标文件中所列工程量有误差时应当允许中标价格作相应调整
# 18                        除中文外还将制作英日等外文版软盘以方便海外用户
# 19                   韩电位于西北电网末端其安全生产对该电网稳定运行有重要意义
# 20               结果可想而知地雷越埋越多越埋越乱越埋越广这山连着那山这片接着那片
# 21                此外与汽车相关的非运输从业人员也达二万多人年可增收五千万元以上
# 22               谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉这些队
# 23               五月的一天下大雨阳台上漏进许多雨水可又没有排水洞只好一盆盆往外端
# 24                        除中文外还将制作英日等外文版软盘以方便海外用户
# 25                    除了付给教师们工资外戴维森自己则获取一年八千英镑的收入
# 26               谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉这些队
# 27                      而盖亚盖亚却持相反的态度所以奥恩将军也对他怀恨在心
# 28             我当时有点昏头想就和他分手算了哪怕登个报纸征婚也行我连稿子都准备好了
# 29               五月的一天下大雨阳台上漏进许多雨水可又没有排水洞只好一盆盆往外端
# ...                                           ...
# 2402             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2403               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2404        经营人员未经旅行社同意不得披露使用或者允许他人使用其所掌握的旅行社商业秘密
# 2405             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面
# 2406             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2407        奥地利二十五日授予奥中友协名誉会长香港环球轮船公司董事长苏海文罗斯托恩勋章
# 2408          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发
# 2409                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样
# 2410             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记
# 2411          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营
# 2412              监管区域为大窑湾港区大连新港港区大连金州区金石滩国家旅游度假区
# 2413             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记
# 2414            非洲葡语国家包括安哥拉莫桑比克几内亚比绍佛得角圣多美和普林西比五国
# 2415            收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人
# 2416          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众
# 2417          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营
# 2418          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发
# 2419            在女子一百米自由泳决赛中我国泳坛女杰乐靖宜以五十四秒五十的成绩折桂
# 2420                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2421                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2422             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面
# 2423                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样
# 2424                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2425             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2426                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2427               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2428               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2429           旅游业是西班牙主要外汇收入来源之一同时也为西班牙创造了大量的就业机会
# 2430          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众
# 2431  天津机场当地也抓住这一有利时机在机场附近开办了民贸市场经营各种国产轻纺产品生意十分火爆
#
#                                               res  wer  word_distance  \
# 0                        我只是要您知道我爱你如果有下辈子我仍愿意做你儿子  1.0              1
# 1                   然而我们应该有其还没有一个严密完整的外来人口管理条例和机构  1.0              1
# 2                           除中文外还将制作英日等外文版以方便海外用户  1.0              1
# 3                         除中文外还将制作英日等外文版转盘一方面海外用户  1.0              1
# 4                         我只是叫您知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 5                         我只是要您知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 6                         我只是要你知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 7                  花卉的产销网络从近郊扩展到省内从省内扩展到省外省外扩展到国外  1.0              1
# 8                         我只是要您知道我爱您如果有下辈子我愿意做你儿子  1.0              1
# 9                     然而我们应该有其他没有一个完整的外来人口管理条例和机构  1.0              1
# 10                    你要我有了爱情的结婚可是我就没有了也找不到了叫我怎么办  1.0              1
# 11         其中匈牙利为三十五亿美元减为二十五亿美元波兰为二十五亿美元俄罗斯达二十亿美元  1.0              1
# 12                        因此农的说女人怎样怎样比说男人怎样怎样要有把握  1.0              1
# 13                 为了使生按计划进行要运用一切科学的原理采取各种避孕节育的措施  1.0              1
# 14                   全国煤炭订货会计人民不受外界干扰因而也成为一个高效率的会  1.0              1
# 15                          除中文外还将制作英日等外文版以方便海外用户  1.0              1
# 16               收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受邀人  1.0              1
# 17                     招标文件中所列工程量有误差应当允许中标价格作相应调整  1.0              1
# 18                          除中文外还将制作音乐等外文版以方便海外用户  1.0              1
# 19                     海淀为西北电网络其安全生产对该电网稳定运行有重要意义  1.0              1
# 20               结果可想而知地雷越来越多越来越乱越来越广这三年的大山这片接着那片  1.0              1
# 21                此外与汽车相关的非运输从业人员也达两万多人年可增收五千万元以上  1.0              1
# 22                  谈到第二阶段淘汰赛王大勇希望先碰法德等欧洲对他很熟悉这些对  1.0              1
# 23               五月的一天下大雨阳台上楼进许多雨水可又没有排水洞只好一盆盆往外端  1.0              1
# 24                        除中文外还将制作工具等外文版软盘以方便海外用户  1.0              1
# 25                      除了付给教师们工资外再为自己获取一年八千英镑的收入  1.0              1
# 26                谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉的队  1.0              1
# 27                       而盖亚盖亚却持相反的态度所以奥将军也被他怀恨在心  1.0              1
# 28               我当时有点昏头想就和他分手算了哪怕登报纸真会也行我稿子都准备好了  1.0              1
# 29                  五月的一天下大雨阳台上的雨水可又没有排水洞只好一盆盆往外端  1.0              1
# ...                                           ...  ...            ...
# 2402             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2403               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2404        经营人员未经旅行社同意不得披露使用或者允许他人使用其所掌握的旅行社商业秘密  0.0              0
# 2405             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面  0.0              0
# 2406             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2407        奥地利二十五日授予奥中友协名誉会长香港环球轮船公司董事长苏海文罗斯托恩勋章  0.0              0
# 2408          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发  0.0              0
# 2409                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样  0.0              0
# 2410             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记  0.0              0
# 2411          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营  0.0              0
# 2412              监管区域为大窑湾港区大连新港港区大连金州区金石滩国家旅游度假区  0.0              0
# 2413             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记  0.0              0
# 2414            非洲葡语国家包括安哥拉莫桑比克几内亚比绍佛得角圣多美和普林西比五国  0.0              0
# 2415            收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人  0.0              0
# 2416          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众  0.0              0
# 2417          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营  0.0              0
# 2418          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发  0.0              0
# 2419            在女子一百米自由泳决赛中我国泳坛女杰乐靖宜以五十四秒五十的成绩折桂  0.0              0
# 2420                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2421                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2422             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面  0.0              0
# 2423                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样  0.0              0
# 2424                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2425             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2426                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2427               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2428               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2429           旅游业是西班牙主要外汇收入来源之一同时也为西班牙创造了大量的就业机会  0.0              0
# 2430          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众  0.0              0
# 2431  天津机场当地也抓住这一有利时机在机场附近开办了民贸市场经营各种国产轻纺产品生意十分火爆  0.0              0
#
#       word_length       cer  char_distance  char_length  len_ratio
# 0               1  0.083333              2           24   1.000000
# 1               1  0.034483              1           29   1.000000
# 2               1  0.086957              2           23   0.913043
# 3               1  0.130435              3           23   1.000000
# 4               1  0.166667              4           24   0.958333
# 5               1  0.125000              3           24   0.958333
# 6               1  0.166667              4           24   0.958333
# 7               1  0.032258              1           31   0.967742
# 8               1  0.083333              2           24   0.958333
# 9               1  0.137931              4           29   0.931034
# 10              1  0.111111              3           27   1.000000
# 11              1  0.051282              2           39   0.974359
# 12              1  0.160000              4           25   0.920000
# 13              1  0.125000              4           32   0.937500
# 14              1  0.137931              4           29   0.965517
# 15              1  0.086957              2           23   0.913043
# 16              1  0.060606              2           33   0.969697
# 17              1  0.037037              1           27   0.962963
# 18              1  0.173913              4           23   0.913043
# 19              1  0.214286              6           28   0.928571
# 20              1  0.218750              7           32   1.000000
# 21              1  0.032258              1           31   1.000000
# 22              1  0.156250              5           32   0.906250
# 23              1  0.031250              1           32   1.000000
# 24              1  0.086957              2           23   1.000000
# 25              1  0.148148              4           27   0.925926
# 26              1  0.062500              2           32   0.968750
# 27              1  0.080000              2           25   0.960000
# 28              1  0.117647              4           34   0.941176
# 29              1  0.125000              4           32   0.906250
# ...           ...       ...            ...          ...        ...
# 2402            1  0.000000              0           32   1.000000
# 2403            1  0.000000              0           30   1.000000
# 2404            1  0.000000              0           37   1.000000
# 2405            1  0.000000              0           32   1.000000
# 2406            1  0.000000              0           32   1.000000
# 2407            1  0.000000              0           37   1.000000
# 2408            1  0.000000              0           35   1.000000
# 2409            1  0.000000              0           28   1.000000
# 2410            1  0.000000              0           32   1.000000
# 2411            1  0.000000              0           35   1.000000
# 2412            1  0.000000              0           31   1.000000
# 2413            1  0.000000              0           32   1.000000
# 2414            1  0.000000              0           33   1.000000
# 2415            1  0.000000              0           33   1.000000
# 2416            1  0.000000              0           35   1.000000
# 2417            1  0.000000              0           35   1.000000
# 2418            1  0.000000              0           35   1.000000
# 2419            1  0.000000              0           33   1.000000
# 2420            1  0.000000              0           23   1.000000
# 2421            1  0.000000              0           23   1.000000
# 2422            1  0.000000              0           32   1.000000
# 2423            1  0.000000              0           28   1.000000
# 2424            1  0.000000              0           23   1.000000
# 2425            1  0.000000              0           32   1.000000
# 2426            1  0.000000              0           23   1.000000
# 2427            1  0.000000              0           30   1.000000
# 2428            1  0.000000              0           30   1.000000
# 2429            1  0.000000              0           34   1.000000
# 2430            1  0.000000              0           35   1.000000
# 2431            1  0.000000              0           43   1.000000
#
# [2432 rows x 10 columns]

# %%
ax = sns.distplot(df['cer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
df_no_issue = df[df['len_ratio'] > 0.75]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 2432
# 2282

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
# Out:
# 0.2857488379132133
# 0.2687036558370549
#
# 0.2857488379132133
# 0.2687036558370549

# %% [markdown]
# # New Hyperparameters

# %%
with open('t_thchs30.json', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    df=pd.DataFrame.from_dict(loaded_json)

df['len_ratio']= df['src'].str.len()/df['res'].str.len()

# %%
df.columns
# Out:
# Index(['cer', 'char_distance', 'char_length', 'loss', 'res', 'src',
#        'wav_filename', 'wer', 'word_distance', 'word_length', 'len_ratio'],
#       dtype='object')

# %%
df[['wav_filename','src', 'res', 'wer', 'word_distance', 'word_length', 'cer', 'char_distance', 'char_length']]
# Out:
#                                            wav_filename  \
# 0     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 1     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 3     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 4     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 5     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 6     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 7     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 8     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 9     /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 10    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 11    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 12    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 13    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 14    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 15    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 16    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 17    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 18    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 19    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 20    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 21    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 22    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 23    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 24    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 25    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 26    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 27    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 28    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 29    /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# ...                                                 ...
# 2402  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2403  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2404  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2405  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2406  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2407  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2408  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2409  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2410  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2411  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2412  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2413  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2414  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2415  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2416  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2417  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2418  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2419  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2420  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2421  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2422  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2423  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2424  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2425  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2426  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2427  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2428  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2429  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2430  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
# 2431  /DeepSpeech/cn_corpus/THCHS_30/data_thchs30/te...
#
#                                               src  \
# 0                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 1                   然而我们应该有却还没有一个严密完整的外来人口管理条例和机构
# 2                         除中文外还将制作英日等外文版软盘以方便海外用户
# 3                         除中文外还将制作英日等外文版软盘以方便海外用户
# 4                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 5                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 6                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 7                 花卉的产销网络从近郊扩展到省内从省内扩展到省外从省外扩展到国外
# 8                        我只是要您知道我爱您如果有下辈子我仍愿意做您儿子
# 9                   然而我们应该有却还没有一个严密完整的外来人口管理条例和机构
# 10                    你要我有了爱情才结婚可是我就没有哇也找不到哇叫我怎么办
# 11        其中匈牙利为三十五亿美元捷克为二十五亿美元波兰为二十五亿美元俄罗斯达二十亿美元
# 12                      因此笼统地说女人怎样怎样比说男人怎样怎样要有把握些
# 13               为了使生育按计划进行就要运用医学科学的原理采取各种避孕节育的措施
# 14                  全国煤炭订货会纪律严明不受外界干扰因而也成为一个高效率的会
# 15                        除中文外还将制作英日等外文版软盘以方便海外用户
# 16              收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人
# 17                    招标文件中所列工程量有误差时应当允许中标价格作相应调整
# 18                        除中文外还将制作英日等外文版软盘以方便海外用户
# 19                   韩电位于西北电网末端其安全生产对该电网稳定运行有重要意义
# 20               结果可想而知地雷越埋越多越埋越乱越埋越广这山连着那山这片接着那片
# 21                此外与汽车相关的非运输从业人员也达二万多人年可增收五千万元以上
# 22               谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉这些队
# 23               五月的一天下大雨阳台上漏进许多雨水可又没有排水洞只好一盆盆往外端
# 24                        除中文外还将制作英日等外文版软盘以方便海外用户
# 25                    除了付给教师们工资外戴维森自己则获取一年八千英镑的收入
# 26               谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉这些队
# 27                      而盖亚盖亚却持相反的态度所以奥恩将军也对他怀恨在心
# 28             我当时有点昏头想就和他分手算了哪怕登个报纸征婚也行我连稿子都准备好了
# 29               五月的一天下大雨阳台上漏进许多雨水可又没有排水洞只好一盆盆往外端
# ...                                           ...
# 2402             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2403               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2404        经营人员未经旅行社同意不得披露使用或者允许他人使用其所掌握的旅行社商业秘密
# 2405             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面
# 2406             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2407        奥地利二十五日授予奥中友协名誉会长香港环球轮船公司董事长苏海文罗斯托恩勋章
# 2408          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发
# 2409                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样
# 2410             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记
# 2411          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营
# 2412              监管区域为大窑湾港区大连新港港区大连金州区金石滩国家旅游度假区
# 2413             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记
# 2414            非洲葡语国家包括安哥拉莫桑比克几内亚比绍佛得角圣多美和普林西比五国
# 2415            收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人
# 2416          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众
# 2417          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营
# 2418          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发
# 2419            在女子一百米自由泳决赛中我国泳坛女杰乐靖宜以五十四秒五十的成绩折桂
# 2420                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2421                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2422             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面
# 2423                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样
# 2424                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2425             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应
# 2426                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址
# 2427               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2428               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全
# 2429           旅游业是西班牙主要外汇收入来源之一同时也为西班牙创造了大量的就业机会
# 2430          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众
# 2431  天津机场当地也抓住这一有利时机在机场附近开办了民贸市场经营各种国产轻纺产品生意十分火爆
#
#                                               res  wer  word_distance  \
# 0                        我只是要您知道我爱你如果有下辈子我仍愿意做你儿子  1.0              1
# 1                   然而我们应该有其还没有一个严密完整的外来人口管理条例和机构  1.0              1
# 2                           除中文外还将制作英日等外文版以方便海外用户  1.0              1
# 3                         除中文外还将制作英日等外文版转盘一方面海外用户  1.0              1
# 4                         我只是叫您知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 5                         我只是要您知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 6                         我只是要你知道我爱你如果有下辈子我愿意做你儿子  1.0              1
# 7                  花卉的产销网络从近郊扩展到省内从省内扩展到省外省外扩展到国外  1.0              1
# 8                         我只是要您知道我爱您如果有下辈子我愿意做你儿子  1.0              1
# 9                     然而我们应该有其他没有一个完整的外来人口管理条例和机构  1.0              1
# 10                    你要我有了爱情的结婚可是我就没有了也找不到了叫我怎么办  1.0              1
# 11         其中匈牙利为三十五亿美元减为二十五亿美元波兰为二十五亿美元俄罗斯达二十亿美元  1.0              1
# 12                        因此农的说女人怎样怎样比说男人怎样怎样要有把握  1.0              1
# 13                 为了使生按计划进行要运用一切科学的原理采取各种避孕节育的措施  1.0              1
# 14                   全国煤炭订货会计人民不受外界干扰因而也成为一个高效率的会  1.0              1
# 15                          除中文外还将制作英日等外文版以方便海外用户  1.0              1
# 16               收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受邀人  1.0              1
# 17                     招标文件中所列工程量有误差应当允许中标价格作相应调整  1.0              1
# 18                          除中文外还将制作音乐等外文版以方便海外用户  1.0              1
# 19                     海淀为西北电网络其安全生产对该电网稳定运行有重要意义  1.0              1
# 20               结果可想而知地雷越来越多越来越乱越来越广这三年的大山这片接着那片  1.0              1
# 21                此外与汽车相关的非运输从业人员也达两万多人年可增收五千万元以上  1.0              1
# 22                  谈到第二阶段淘汰赛王大勇希望先碰法德等欧洲对他很熟悉这些对  1.0              1
# 23               五月的一天下大雨阳台上楼进许多雨水可又没有排水洞只好一盆盆往外端  1.0              1
# 24                        除中文外还将制作工具等外文版软盘以方便海外用户  1.0              1
# 25                      除了付给教师们工资外再为自己获取一年八千英镑的收入  1.0              1
# 26                谈到第二阶段淘汰赛王大勇希望先碰瑞法德等欧洲队因为他很熟悉的队  1.0              1
# 27                       而盖亚盖亚却持相反的态度所以奥将军也被他怀恨在心  1.0              1
# 28               我当时有点昏头想就和他分手算了哪怕登报纸真会也行我稿子都准备好了  1.0              1
# 29                  五月的一天下大雨阳台上的雨水可又没有排水洞只好一盆盆往外端  1.0              1
# ...                                           ...  ...            ...
# 2402             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2403               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2404        经营人员未经旅行社同意不得披露使用或者允许他人使用其所掌握的旅行社商业秘密  0.0              0
# 2405             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面  0.0              0
# 2406             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2407        奥地利二十五日授予奥中友协名誉会长香港环球轮船公司董事长苏海文罗斯托恩勋章  0.0              0
# 2408          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发  0.0              0
# 2409                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样  0.0              0
# 2410             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记  0.0              0
# 2411          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营  0.0              0
# 2412              监管区域为大窑湾港区大连新港港区大连金州区金石滩国家旅游度假区  0.0              0
# 2413             由王震王首道贺炳炎廖汉生王恩茂等八人组成军政委员会以王首道为书记  0.0              0
# 2414            非洲葡语国家包括安哥拉莫桑比克几内亚比绍佛得角圣多美和普林西比五国  0.0              0
# 2415            收购要约发出后主要要约条件改变的收购要约人应当立即通知所有受要约人  0.0              0
# 2416          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众  0.0              0
# 2417          企业发行企业债券所筹资金应当按照审批机关批准的用途用于本企业的生产经营  0.0              0
# 2418          国务院出于安全考虑没有透露谁将前往喀布尔也不透露这位外交官将从何地出发  0.0              0
# 2419            在女子一百米自由泳决赛中我国泳坛女杰乐靖宜以五十四秒五十的成绩折桂  0.0              0
# 2420                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2421                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2422             吉隆坡郊外一座十二层公寓十一日下午突然倒塌将五十多名房客困在里面  0.0              0
# 2423                 不仅要宣传少生还要宣传晚婚晚育优生优育宣传生男生女都一样  0.0              0
# 2424                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2425             望子成龙望女成凤的父母亲爷爷奶奶外公外婆只要孩子听话总是有求必应  0.0              0
# 2426                      带着诸多疑问迎着和煦的春风我们走访了圆明园遗址  0.0              0
# 2427               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2428               运动员村必须用铁栏杆围起来有武装警卫站岗以保证运动员绝对安全  0.0              0
# 2429           旅游业是西班牙主要外汇收入来源之一同时也为西班牙创造了大量的就业机会  0.0              0
# 2430          国务委员兼国务院秘书长罗干民政部部长多吉才让也一同前往延安看望人民群众  0.0              0
# 2431  天津机场当地也抓住这一有利时机在机场附近开办了民贸市场经营各种国产轻纺产品生意十分火爆  0.0              0
#
#       word_length       cer  char_distance  char_length
# 0               1  0.083333              2           24
# 1               1  0.034483              1           29
# 2               1  0.086957              2           23
# 3               1  0.130435              3           23
# 4               1  0.166667              4           24
# 5               1  0.125000              3           24
# 6               1  0.166667              4           24
# 7               1  0.032258              1           31
# 8               1  0.083333              2           24
# 9               1  0.137931              4           29
# 10              1  0.111111              3           27
# 11              1  0.051282              2           39
# 12              1  0.160000              4           25
# 13              1  0.125000              4           32
# 14              1  0.137931              4           29
# 15              1  0.086957              2           23
# 16              1  0.060606              2           33
# 17              1  0.037037              1           27
# 18              1  0.173913              4           23
# 19              1  0.214286              6           28
# 20              1  0.218750              7           32
# 21              1  0.032258              1           31
# 22              1  0.156250              5           32
# 23              1  0.031250              1           32
# 24              1  0.086957              2           23
# 25              1  0.148148              4           27
# 26              1  0.062500              2           32
# 27              1  0.080000              2           25
# 28              1  0.117647              4           34
# 29              1  0.125000              4           32
# ...           ...       ...            ...          ...
# 2402            1  0.000000              0           32
# 2403            1  0.000000              0           30
# 2404            1  0.000000              0           37
# 2405            1  0.000000              0           32
# 2406            1  0.000000              0           32
# 2407            1  0.000000              0           37
# 2408            1  0.000000              0           35
# 2409            1  0.000000              0           28
# 2410            1  0.000000              0           32
# 2411            1  0.000000              0           35
# 2412            1  0.000000              0           31
# 2413            1  0.000000              0           32
# 2414            1  0.000000              0           33
# 2415            1  0.000000              0           33
# 2416            1  0.000000              0           35
# 2417            1  0.000000              0           35
# 2418            1  0.000000              0           35
# 2419            1  0.000000              0           33
# 2420            1  0.000000              0           23
# 2421            1  0.000000              0           23
# 2422            1  0.000000              0           32
# 2423            1  0.000000              0           28
# 2424            1  0.000000              0           23
# 2425            1  0.000000              0           32
# 2426            1  0.000000              0           23
# 2427            1  0.000000              0           30
# 2428            1  0.000000              0           30
# 2429            1  0.000000              0           34
# 2430            1  0.000000              0           35
# 2431            1  0.000000              0           43
#
# [2432 rows x 9 columns]

# %%
ax = sns.distplot(df['cer'], bins=10) # blue
sns.distplot(df['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()

# %%
sns.distplot(df['len_ratio'], color="g", kde_kws={"shade": True}, hist=False, rug=True)

# %%
sns.distplot(df['len_ratio'], bins=20, kde=True, rug=False)

# %%
df_no_issue = df[df['len_ratio'] > 0.75]
print(len(df))
print(len(df_no_issue))
ax = sns.distplot(df_no_issue['cer'], bins=10) # blue
sns.distplot(df_no_issue['cer'], bins=10) # orange
ax.set(xlabel='Error Rate', ylabel='Density')
plt.show()
# Out:
# 2432
# 2432

# %%
print(df['cer'].mean())
print(df_no_issue['cer'].mean())
print()
print(df['wer'].mean())
print(df_no_issue['wer'].mean())
# Out:
# 0.2857488379132133
# 0.2857488379132133
#
# 0.9683388157894737
# 0.9683388157894737
