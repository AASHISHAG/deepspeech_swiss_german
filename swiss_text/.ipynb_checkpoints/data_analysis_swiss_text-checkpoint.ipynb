# %%
import json
import string
import jiwer as ji
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Section1: Data Loading

# %% [markdown]
# This section is used for pre-processing the dataset.

# %% [markdown]
# ### 1. DeepSpeech (with optimised alpha beta)

# %%
deepspeech_train = pd.DataFrame()
deepspeech_dev = pd.DataFrame()
deepspeech_test = pd.DataFrame()

# %%
with open('deepspeech_train.txt', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    deepspeech_train = pd.DataFrame.from_dict(loaded_json)

with open('deepspeech_dev.txt', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    deepspeech_dev = pd.DataFrame.from_dict(loaded_json)
    
with open('deepspeech_test.txt', 'r', encoding='utf-8') as file_read:
    data = file_read.read()
    loaded_json = json.loads(data)
    deepspeech_test = pd.DataFrame.from_dict(loaded_json)

# %%
def replacePath(x):
    return x.split("/media/data/LTLab.lan/agarwal/german-speech-corpus/swiss_german/splits_mathias/clips/")[1]

def replacePath2(x):
    return x.split(".wav")[0]

deepspeech_train['wav_filename'] = deepspeech_train['wav_filename'].apply(replacePath)
deepspeech_dev['wav_filename'] = deepspeech_dev['wav_filename'].apply(replacePath)
deepspeech_test['wav_filename'] = deepspeech_test['wav_filename'].apply(replacePath)

deepspeech_train['wav_filename'] = deepspeech_train['wav_filename'].apply(replacePath2)
deepspeech_dev['wav_filename'] = deepspeech_dev['wav_filename'].apply(replacePath2)
deepspeech_test['wav_filename'] = deepspeech_test['wav_filename'].apply(replacePath2)

# %%
deepspeech_train['length_ratio'] = deepspeech_train['res'].str.len()/deepspeech_train['src'].str.len()
deepspeech_dev['length_ratio'] = deepspeech_dev['res'].str.len()/deepspeech_dev['src'].str.len()
deepspeech_test['length_ratio'] = deepspeech_test['res'].str.len()/deepspeech_test['src'].str.len()

# %%
deepspeech_train = deepspeech_train[['wav_filename', 'src', 'res', 'wer', 'length_ratio']]
deepspeech_train = deepspeech_train.sort_values('wav_filename',ascending=True)
deepspeech_train = deepspeech_train.rename(columns={'res': 'res_dp', 'wer': 'wer_dp', 'length_ratio': 'length_ratio_dp'})
deepspeech_train.set_index('wav_filename')

deepspeech_dev = deepspeech_dev[['wav_filename', 'src', 'res', 'wer', 'length_ratio']]
deepspeech_dev = deepspeech_dev.sort_values('wav_filename',ascending=True)
deepspeech_dev = deepspeech_dev.rename(columns={'res': 'res_dp', 'wer': 'wer_dp', 'length_ratio': 'length_ratio_dp'})
deepspeech_dev.set_index('wav_filename')

deepspeech_test = deepspeech_test[['wav_filename', 'src', 'res', 'wer', 'length_ratio']]
deepspeech_test = deepspeech_test.sort_values('wav_filename',ascending=True)
deepspeech_test = deepspeech_test.rename(columns={'res': 'res_dp', 'wer': 'wer_dp', 'length_ratio': 'length_ratio_dp'})
deepspeech_test.set_index('wav_filename')
# Out:
#                                                             src  \
# wav_filename
# 10090         aber ich habe etwas mühe für die bdp zu sprech...
# 10091         wir unterstützen die motion sie geht in die ri...
# 10092         die antwort des regierungsrats ist eben leider...
# 10093         es geht nicht um eine doppelte bestrafung der ...
# 10094         der taxifahrer der vielleicht einmal zu schnel...
# 10095         der taxifahrer wird dreimal bestraft und dies ...
# 10096         deshalb muss diese kehrtwende kommen und wir k...
# 10097         sie wissen ja welche landessprache die taxifah...
# 10098         diese leute mit entsprechendem migrationshinte...
# 10221              unsere fraktion schliesst sich der motion an
# 10222         denn es handelt sich nur um eine richtlinienmo...
# 10223              auch uns geht es darum ein zeichen zu setzen
# 10230                 die edu fraktion unterstützt diese motion
# 10231                                wir sind gegen besetzungen
# 10232             jedoch wollen wir zwischennutzungen anstreben
# 10233                     deshalb sagen wir ja zu dieser motion
# 10270         berücksichtigung öffentlicher interessen beim ...
# 10271         aber wir sehen das öffentliche interesse beim ...
# 10272         wir müssen den kanton vertreten oder ist hier ...
# 10273                        ich komme zu den einzelnen punkten
# 10274         beim beabsichtigten verkauf abzuklären ob jema...
# 10275         der verkauf wird ausgeschrieben und die gemein...
# 10276         der gewerbetreibende muss gleich behandelt werden
# 10277         diesen punkt 1 hätten wir als motion trotz uns...
# 10278              als postulat stimmen wir ihm mehrheitlich zu
# 10279         ich ärgere mich noch heute über den verkauf de...
# 10280         ich bin überzeugt dass man einen viel höheren ...
# 10281         wir sind nicht in der situation so etwas tun z...
# 10282         betreffend das vorkaufsrecht sehen wir es glei...
# 10283         ein solches kann gewisse interessenten darin h...
# ...                                                         ...
# 8380          es sind jene welche der kanton die gef und reg...
# 8381          wer entscheidet denn ob die vorläufig aufgenom...
# 8548          hier geht es noch einmal um das wörtchen grund...
# 8712                                     es ist härter geworden
# 8713          aber wenn es irgendeinmal etwas schwieriger un...
# 8714          aber wir müssen aufpassen dass nicht der unter...
# 885           die fin hat sich zur wehr gesetzt und gesagt e...
# 886           dies ist einer der hauptgründe für dieses problem
# 8940          die edu fraktion ist sich bewusst dass das gel...
# 8941          wir stimmen diesem kredit zu und lehnen den rü...
# 9014          wir sind aber froh um die präzisierung denn wi...
# 9015          aber die pragmatische lösung so wie sie jetzt ...
# 9188          die exposition im jugendalter im strassenverke...
# 9189          auch die unfallstatistik spricht klar für dies...
# 9190          es ist wichtig dass alle schülerinnen und schü...
# 9191          der abbruch nach der sechsten klasse ist eine ...
# 9298          mich würde zudem interessieren was grossrat wü...
# 9364          damit werden unbewilligte demonstrationen de f...
# 9412            wer schäden verursacht muss auch dafür bezahlen
# 9445          man hat sogar eine platzkundgebung gemacht wei...
# 9522          andernfalls schiesst das ganze thema der kompe...
# 9523          weil er genau weiss dass man am wochenende und...
# 9987          das ziel ist es einen bestimmten typus von asy...
# 9988          ich denke an all die jungen pseudo asylantrags...
# 9989          das anliegen ist eine negative attraktivitätss...
# 9990          sie will den vorstoss annehmen und auch gleich...
# 9991                       das geht mir jedoch etwas zu schnell
# 9992          mein antrag lautet auf nichtabschreibung des v...
# 9993                      es handelt sich um die gängige praxis
# 9994          selbst wenn man diese motion annehmen und absc...
#
#                                                          res_dp    wer_dp  \
# wav_filename
# 10090               ein bis er die bdp zu sprechen es gleich in  0.705882
# 10091         wir unterstützen die motion unterstützen die m...  0.500000
# 10092                      die antwort des rates die leider als  0.500000
# 10093         ich eine doppelte bestrafen der taxifahrer ein...  0.714286
# 10094         der taxifahrer der eichel gefahr gibt den bus ...  0.666667
# 10095         der taxifahrer wird dreimal bestraft und das i...  0.230769
# 10096         aus dieser wenn und kommen und wir können hier...  0.571429
# 10097         in welcher landessprachen die taxifahrer haben...  0.875000
# 10098         leute mit diesem migrationshintergrund sollte ...  0.250000
# 10221                                    in einer motion an ein  0.857143
# 10222         nur ein richtlinie motion und in uns kontenfüh...  0.695652
# 10223                               uns geht es um ein zeichen   0.444444
# 10230                 die edu fraktion unterstützt diese motion  0.000000
# 10231                                wir sind gegen besetzungen  0.000000
# 10232                   in den wir zwischen nutzungen anstreben  0.800000
# 10233                                   sagen wir ja zur motion  0.428571
# 10270         berücksichtigung öffentlicher interessen beim ...  0.500000
# 10271                 aber wie sehen die öffentliche mit seinen  0.625000
# 10272         in der wir müssten kanton bern oder ist irgend...  0.769231
# 10273                                  zu den einzelnen punkten  0.333333
# 10274         bei beabsichtigen verkauf abklären ob jemand i...  0.352941
# 10275         die ausgeschriebene kannte und melden wie der ...  0.714286
# 10276                         das ausmass gleich behandelt wird  0.666667
# 10277         in den hatten wir als motion go abgelehnt trat...  0.833333
# 10278                       es hat ulmen wir im mehrheitlich zu  0.571429
# 10279         die noch über den verkauften vier felder der o...  0.500000
# 10280                 ich bin überzeugt man hat ein viel lösen   0.666667
# 10281           es sind nicht in der situation so tun zu können  0.181818
# 10282                     wegen des vorhauses wie regierungsrat  0.800000
# 10283         das kann gewisse in der senten hen ein artgere...  0.750000
# ...                                                         ...       ...
# 8380          die der kantone und regierungsrat schnee begin...  0.636364
# 8381          es entscheidet über die vorläufig aufgenommen ...  0.400000
# 8548                           wie geht es und es grundsätzlich  0.666667
# 8712                                            es ist hatte er  0.500000
# 8713          aber wenn irgendein nach ein schwieriger wirts...  0.703704
# 8714          aber wir müssen aufpassen dass nicht der unter...  0.333333
# 885           er hat man sich durchgesetzt der sich zur wehr...  0.857143
# 886           es ist einer der hauptgründe weshalb es zu die...  0.625000
# 8940          in der edu fraktion ist uns bewusst dass er da...  0.666667
# 8941          in diesem kredit und lehen der rückweisung ant...  0.700000
# 9014          der frau die er in ungerader dem sogenannten d...  0.947368
# 9015                 die nische lösung sowie einen unterstützen  0.785714
# 9188          die exposition in jugend alter im strassenverk...  0.333333
# 9189          die statistik spricht klar für die art von prä...  0.300000
# 9190          es ist wichtig dass alle schülerinnen und schü...  0.217391
# 9191          der abbruch nach der s klasse ist es verpasst ...  0.476190
# 9298          wir mischen wir interessieren was in der präsi...  0.615385
# 9364          er will die demonstrationen de fato für unmöglich  0.857143
# 9412                        wer verursacht muss auch der zahlen  0.428571
# 9445          da sämtliche auflagen tensoren platz unter ver...  1.000000
# 9522          es bildete reihenweise damit als man ein solch...  1.333333
# 9523                      diese woche am frieden ist man fragt   0.923077
# 9987          in bestimmten typus bestimmten typus asylbewer...  0.764706
# 9988          in den ist die junge asyl zusteller aus eritre...  0.823529
# 9989          als im sinn einer negativen attraktivitätsstei...  0.833333
# 9990          die weigerung der vorstoss annehmen die aber a...  0.666667
# 9991                                  das geht mir aber schnell  0.428571
# 9992                                               der absender  1.000000
# 9993                       in der zeit auf dem tiefstand jahren  1.000000
# 9994          in dem die motion minen und abschreiben ändert...  0.846154
#
#               length_ratio_dp
# wav_filename
# 10090                0.511905
# 10091                1.180328
# 10092                0.679245
# 10093                0.593407
# 10094                0.692308
# 10095                0.936842
# 10096                0.956044
# 10097                0.862069
# 10098                0.848485
# 10221                0.500000
# 10222                0.614815
# 10223                0.613636
# 10230                1.000000
# 10231                1.000000
# 10232                0.866667
# 10233                0.621622
# 10270                0.979381
# 10271                0.745455
# 10272                0.933333
# 10273                0.705882
# 10274                0.975000
# 10275                0.672515
# 10276                0.673469
# 10277                0.939759
# 10278                0.795455
# 10279                0.970588
# 10280                0.561644
# 10281                0.870370
# 10282                0.528571
# 10283                0.761364
# ...                       ...
# 8380                 0.676056
# 8381                 0.962963
# 8548                 0.592593
# 8712                 0.681818
# 8713                 0.616766
# 8714                 0.791209
# 885                  1.131579
# 886                  1.163265
# 8940                 0.650000
# 8941                 0.800000
# 9014                 0.508065
# 9015                 0.461538
# 9188                 1.011111
# 9189                 0.803030
# 9190                 0.881081
# 9191                 0.955224
# 9298                 0.711340
# 9364                 0.765625
# 9412                 0.744681
# 9445                 0.801980
# 9522                 1.522727
# 9523                 0.500000
# 9987                 0.772277
# 9988                 0.930000
# 9989                 0.945455
# 9990                 0.965517
# 9991                 0.694444
# 9992                 0.218182
# 9993                 0.972973
# 9994                 0.869048
#
# [1800 rows x 4 columns]

# %% [markdown]
# ### 2. Jasper

# %%
jasper_train = pd.DataFrame()
jasper_dev = pd.DataFrame()
jasper_test = pd.DataFrame()

# %%
data = []
with open('jasper_train.txt') as f:
    for row_num, line in enumerate(f):
        if line is not '\n':
            try:
                wav_filename = line.split('#')[0].rstrip('\t')
                res = line.split('#')[1].strip('\n').strip('\t').replace("\t", " ")
                match = deepspeech_train[deepspeech_train['wav_filename'].str.match(wav_filename)]
                src = match['src'].iloc[0]
                wer = ji.wer(src, res)
                length_ratio = len(res)/len(src)
                data.append([wav_filename, res, src, wer, length_ratio])
            except:
                print(wav_filename)
jasper_train = pd.DataFrame(data = data, columns = ['wav_filename', 'res_js', 'src', 'wer_js', 'length_ratio_js'])

# %%
data = []
with open('jasper_dev.txt') as f:
    for row_num, line in enumerate(f):
        if line is not '\n':
            try:
                wav_filename = line.split('#')[0].rstrip('\t')
                res = line.split('#')[1].strip('\n').strip('\t').replace("\t", " ")
                match = deepspeech_dev[deepspeech_dev['wav_filename'].str.match(wav_filename)]
                src = match['src'].iloc[0]
                wer = ji.wer(src, res)
                length_ratio = len(res)/len(src)
                data.append([wav_filename, res, src, wer, length_ratio])
            except:
                print(wav_filename)
jasper_dev = pd.DataFrame(data = data, columns = ['wav_filename', 'res_js', 'src', 'wer_js', 'length_ratio_js'])

# %%
data = []
with open('jasper_test.txt') as f:
    for row_num, line in enumerate(f):
        if line is not '\n':
            try:
                wav_filename = line.split('#')[0].rstrip('\t')
                res = line.split('#')[1].strip('\n').strip('\t').replace("\t", " ")
                match = deepspeech_test[deepspeech_test['wav_filename'].str.match(wav_filename)]
                src = match['src'].iloc[0]
                wer = ji.wer(src, res)
                length_ratio = len(res)/len(src)
                data.append([wav_filename, res, src, wer, length_ratio])
            except:
                print(wav_filename)
jasper_test = pd.DataFrame(data = data, columns = ['wav_filename', 'res_js', 'src', 'wer_js', 'length_ratio_js'])

# %%
jasper_train = jasper_train[['wav_filename', 'src', 'res_js', 'wer_js', 'length_ratio_js']]
jasper_train = jasper_train.sort_values('wav_filename',ascending=True)
jasper_train = jasper_train.set_index('wav_filename')

jasper_dev = jasper_dev[['wav_filename', 'src', 'res_js', 'wer_js', 'length_ratio_js']]
jasper_dev = jasper_dev.sort_values('wav_filename',ascending=True)
jasper_dev = jasper_dev.set_index('wav_filename')

jasper_test = jasper_test[['wav_filename', 'src', 'res_js', 'wer_js', 'length_ratio_js']]
jasper_test = jasper_test.sort_values('wav_filename',ascending=True)
jasper_test = jasper_test.set_index('wav_filename')

# %%
jasper_test

# %% [markdown]
# ### 3. Kaldi

# %%
kaldi = pd.read_csv('kaldi_test.csv', encoding='utf-8')

# %%
def updatePath(path):
    return path.split("-")[1].split('.')[0]

kaldi["wav_filename"] = kaldi["wav_filename"].apply(updatePath)

# %%
wer = []
length_ratio = []
for index, row in kaldi.iterrows():
    try:
        wav_filename = row['wav_filename']
        res = row['res']
        match = deepspeech_test[deepspeech_test['wav_filename'].str.match(wav_filename)]
        src = match['src'].iloc[0]
        wer = round(ji.wer(src, res)*100,2)
        length_ratio = len(res)/len(src)
        data.append([wav_filename, res, src, wer, length_ratio])
    except:
        print(wav_filename)
kaldi_test = pd.DataFrame(data = data, columns = ['wav_filename', 'res_kd', 'src', 'wer_kd', 'length_ratio_kd'])

# %% [markdown]
# ### 4. Private Test Data

# %%
grndthruth_test_pri = pd.read_csv('test_public_ground_truth.csv')
grndthruth_test_pri['sentence'] = grndthruth_test_pri.sentence.str.replace('[^\w\s]','')
grndthruth_test_pri = grndthruth_test_pri.rename(columns={'path': 'wav_filename', 'sentence': 'src'})
grndthruth_test_pri = grndthruth_test_pri.set_index('wav_filename')

fhnw_test_pri = pd.read_csv('test_public_submission_fhnw.csv')
fhnw_test_pri = fhnw_test_pri.rename(columns={'path': 'wav_filename', 'sentence': 'res_fhnw'})
fhnw_test_pri = fhnw_test_pri.set_index('wav_filename')

ude_test_pri = pd.read_csv('test_public_submission_ude.csv')
ude_test_pri = ude_test_pri.rename(columns={'path': 'wav_filename', 'sentence': 'res_ude'})
ude_test_pri = ude_test_pri.set_index('wav_filename')

uzh_test_pri = pd.read_csv('test_public_submission_uzh.csv')
uzh_test_pri = uzh_test_pri.rename(columns={'path': 'wav_filename', 'sentence': 'res_uzh'})
uzh_test_pri = uzh_test_pri.set_index('wav_filename')

zhaw_test_pri = pd.read_csv('test_public_submission_zhaw.csv')
zhaw_test_pri = zhaw_test_pri.rename(columns={'path': 'wav_filename', 'sentence': 'res_zhaw'})
zhaw_test_pri = zhaw_test_pri.set_index('wav_filename')

# %%
combined_test_pri = pd.concat([grndthruth_test_pri, fhnw_test_pri, ude_test_pri, uzh_test_pri, zhaw_test_pri], axis=1)
combined_test_pri.loc[:,~combined_test_pri.columns.duplicated()]

combined_test_pri = combined_test_pri.dropna()

# %%
wer = []
length_ratio = []
for index, row in combined_test_pri.iterrows():
    wer.append(round(ji.wer(row['src'], row['res_fhnw'])*100,2))
    length_ratio.append(len(row['res_fhnw'])/len(row['src']))
combined_test_pri['res_fhnw_wer'] = wer
combined_test_pri['length_ratio_fhnw'] = length_ratio
    
wer = []
length_ratio = []
for index, row in combined_test_pri.iterrows():
    wer.append(round(ji.wer(row['src'], row['res_ude'])*100,2))
    length_ratio.append(len(row['res_ude'])/len(row['src']))                                    
combined_test_pri['res_ude_wer'] = wer
combined_test_pri['length_ratio_ude'] = length_ratio
    
wer = []
length_ratio = []
for index, row in combined_test_pri.iterrows():
    wer.append(round(ji.wer(row['src'], row['res_uzh'])*100,2))
    length_ratio.append(len(row['res_uzh'])/len(row['src']))
combined_test_pri['res_uzh_wer'] = wer
combined_test_pri['length_ratio_uzh'] = length_ratio
    
wer = []
length_ratio = []
for index, row in combined_test_pri.iterrows():
    wer.append(round(ji.wer(row['src'], row['res_zhaw'])*100,2))
    length_ratio.append(len(row['res_zhaw'])/len(row['src']))   
combined_test_pri['res_zhaw_wer'] = wer
combined_test_pri['length_ratio_zhaw'] = length_ratio

# %%
combined_test_pri
# Out:
#                                                             src  \
# wav_filename
# 15.flac       vielen dank für diese grosse arbeit im dienste...
# 16.flac       und vielen dank an dieser stelle auch für die ...
# 70.flac                     ich komme zum zweiten vizepräsidium
# 242.flac      wir sind jedoch froh dass der regierungsrat di...
# 243.flac      das betreuungsverhältnis in den tagesschulen b...
# 244.flac      hier ist unseres erachtens anpassungspotenzial...
# 245.flac      diese erkenntnis hat sicher für die ganze schw...
# 246.flac      in den kantonen zürich basellandschaft aargau ...
# 247.flac      zum nächsten postulat die svp fraktion unterst...
# 248.flac      wir sind ebenfalls der meinung dass eine klass...
# 258.flac        zuerst möchte ich der fdp ein kompliment machen
# 259.flac             sie sind beim regierungsrat vorausgegangen
# 286.flac      die bdp fraktion bedauert natürlich dass der k...
# 287.flac      die bdp fraktion unterstützt das gesetz daher ...
# 316.flac      der zeitpunkt scheint uns richtig und wichtig ...
# 317.flac            die bdp unterstützt diese motion einstimmig
# 471.flac      das tram erlebt heute fast weltweit eine renai...
# 472.flac      ich zitiere hier wörtlich aus dem protokoll de...
# 476.flac      wer von münsingen an die reiterstrasse gelange...
# 652.flac      bravo auch an die baudirektion für den mut ein...
# 653.flac         der transport wird in minergie p eco gewichtet
# 655.flac      zu auflage 4 ein aufbretzeln von normteilen ha...
# 701.flac      es liegt natürlich in der natur der sache dass...
# 702.flac      mit diesem kredit werden jährlich 800 bis 1100...
# 703.flac      im portfolio des kantons bern befinden sich ru...
# 704.flac      im weiteren wurden die limiten für benutzerspe...
# 705.flac      der rahmenkredit liegt gegenüber dem letzten r...
# 708.flac      sie legt eine sehr hohe kostendisziplin an den...
# 747.flac      mit diesem leuchttürmchen wollen wir ein klare...
# 749.flac      es ist nicht einfach ein stallbau kilian bauma...
# ...                                                         ...
# 37310.flac            das ist etwas das wieder sehr beliebt ist
# 37312.flac    die letzten kompositionen man konnte es in der...
# 37313.flac    jetzt eine klimadebatte später werden die nach...
# 37315.flac    neue linien zu finanzieren ist nicht in der ko...
# 37316.flac    das ist nach dem gestrigen tag und der abstimm...
# 37317.flac    der prototyp wäre vielleicht auch dort zu best...
# 37596.flac    weiter haben wir erfahren dass die kosten der ...
# 37598.flac    die studierenden können das studienprogramm in...
# 37599.flac    die ph bern reagiert mit diesem angebot ab 202...
# 37600.flac    auch die jahresrechnung 2018 der ph bern schli...
# 37601.flac    das beitragssystem als solches hat sich aus si...
# 37602.flac    die damit verbundene finanzautonomie gibt der ...
# 37603.flac    es ist offensichtlich dass für den kanton bern...
# 37683.flac    wie gesagt alle diese antworten auf ihre frage...
# 37684.flac    würde die sicherheit der bevölkerung durch die...
# 37686.flac    im übrigen ist die beantwortung der motion dur...
# 37750.flac    wer dies ganz natürlich in der familie und im ...
# 37751.flac    fähigkeiten und fertigkeiten werden insbesonde...
# 37752.flac     es gibt jedoch ein grosses aber bei diesem thema
# 37753.flac    wissen und selbstverantwortung sind ein zu gro...
# 37824.flac    dass sich der regierungsrat diesen aufgaben gr...
# 37829.flac    genauso sollte der unterricht in den klassenzi...
# 37831.flac    wenn beidseitig bei auftraggeber und auftragne...
# 38001.flac    wir schliessen uns dem allgemeinen dank an und...
# 38002.flac    der masterplan versucht den vorgegebenen eckpu...
# 38003.flac    nebst sanierungs und modernisierungsbedarf wer...
# 38348.flac    es begann unter herrn regierungsrat neuhaus un...
# 38479.flac    aus spezialfinanzierungen sowie fonds und vorf...
# 38480.flac    die verschuldung ist weniger gross als beim ka...
# 38481.flac    es wäre genau die gleiche rechtslage wie sie d...
#
#                                                        res_fhnw  \
# wav_filename
# 15.flac         für die grosse arbeit im dienst unseres kantons
# 16.flac       wir sind an dieser stelle auch für die gesamme...
# 70.flac                     ich komme zum zweiten vizepräsidium
# 242.flac      wir sind aber froh dass der regierungsrat dies...
# 243.flac      die betreuungsverhältnisse bei den tagesschule...
# 244.flac      hier ist unseres erachtens auch noch anpassung...
# 245.flac      diese erkenntnis hat sicher für die ganze schw...
# 246.flac      diejenigen an den kosten der schulgänzenden be...
# 247.flac      zum nächsten postulat die kindergärten einheit...
# 248.flac      wir sind ebenfalls der meinung dass eine kasse...
# 258.flac      ich möchte zuerst einmal eine fdp ein komplime...
# 259.flac                  deshalb ist der regierungsrat bekannt
# 286.flac      die bdp fraktion bedauert es natürlich dass de...
# 287.flac      mit einem geringen augen das gesetz und ebenso...
# 316.flac      der zeitpunkt sind uns durchaus richtig und wi...
# 317.flac            die bdp unterstützt diese motion einstimmig
# 471.flac       das tram erlebt heute fast weltweit eine rönisse
# 472.flac      ich zitiere hier wörtlich aus dem protokoll de...
# 476.flac      nämlich der von münsingen an die dritte strass...
# 652.flac      bravo einer baudirektion für den mut die ein h...
# 653.flac      dieser transport wird gewichtet in minergie pegco
# 655.flac      der punkt 4 das auftreten von einem teile halb...
# 701.flac      es liegt in der natur der sache dass die durch...
# 702.flac      mit diesem kredit werden jährlich 800 bis 100 ...
# 703.flac      im portfolio des kantons bern sind rund 200 40...
# 704.flac      im weiteren sind die limiten für benutzerspezi...
# 705.flac      dieser rahmenkredit ist gegenüber dem letzten ...
# 708.flac      es geht um eine sehr hohe kostendisziplin wenn...
# 747.flac      nur eine solche dürmeln wollen wir ein klares ...
# 749.flac      es ist nicht einfach eine stahlbau liebe kilia...
# ...                                                         ...
# 37310.flac              schon wieder etwas das sehr beliebt ist
# 37312.flac    die letzten kompositionen konnten lesen in der...
# 37313.flac    und jetzt eine klimadebatte später werden die ...
# 37315.flac    neue linien zu finanzieren ist nicht der kompe...
# 37316.flac    sie haben nach dem gestrigen tag und der absti...
# 37317.flac    also der rottyp werden vielleicht auch dort zu...
# 37596.flac    leider haben wir erfahren dass die kosten der ...
# 37598.flac    die studierenden können das studienprogramm in...
# 37599.flac    die ph reagiert mit diesem angebot ab 2021 auf...
# 37600.flac    auch die jahresrechnung 2018 der ph schliesse ...
# 37601.flac       das thema so hat sich aus sicht der ph bewährt
# 37602.flac    die damit verbundene finanzautonomie gibt der ...
# 37603.flac    es ist offensichtlich dass für den kanton bern...
# 37683.flac    wie gesagt alle antworten auf ihre fragen wäre...
# 37684.flac    die sicherheit der bevölkerung wird durch die ...
# 37686.flac    im übrigen ist die beantwortung der motion dur...
# 37750.flac    das ganz natürliche familien und umfeld auf di...
# 37751.flac    viertens und fertigkeiten werden im besonderen...
# 37752.flac             es gibt ein grosses aber in diesem thema
# 37753.flac    wissen und selbstverantwortung ist es ein gros...
# 37824.flac    dass sich der regierungsrat den aufgaben grund...
# 37829.flac    ebenso sollten die unterricht in den klassenzi...
# 37831.flac    wenn bei auftraggeber und auftraggeber die gle...
# 38001.flac    wir schliessen uns dem allgemeinen dank an und...
# 38002.flac    der masterplan versucht den vorgegebenen eckpu...
# 38003.flac    selbst die sanierungs und modernungsbedarf wer...
# 38348.flac    es handelt sich um den regierungsrat neuhaus u...
# 38479.flac    aus spezialfinanzierungen und vorfinanzierunge...
# 38480.flac    die verschuldung ist weniger gross als beim ka...
# 38481.flac    selbstverständlich vereinfachen es wäre genau ...
#
#                                                         res_ude  \
# wav_filename
# 15.flac                 für die grosse arbeit im dienste kanton
# 16.flac       dieser stelle für die gesammelten werke der ge...
# 70.flac                     ich komme zum zweiten vizepräsidium
# 242.flac      sie haben frau dass der regierungsrat die post...
# 243.flac      die bereits bei der tagesschule beträgt ein fü...
# 244.flac                                 es ist unser chennault
# 245.flac      diese erkenntnis hat sich für die ganze schwei...
# 246.flac      an den kosten der schul ergänzenden betreuunge...
# 247.flac      zum nächsten postulat kindheitlichen für die f...
# 248.flac      wir die ebenfalls der meinung dass eine klasse...
# 258.flac                           ich erstmal rechtskommentare
# 259.flac                              der regierungsrat bekannt
# 286.flac      b fraktion bedauere natürlich dass der kanton ...
# 287.flac      erst mit mit denen gegenden das gesetz und ebe...
# 316.flac      der zeitpunkt richtig und wichtig weil wir län...
# 317.flac                          es unterstützt die motion ein
# 471.flac                                 das erlebte eine ronan
# 472.flac      in zierlichen protokoll der debatte vor fünf j...
# 476.flac      nämlich die von nun an der strasse ab weinzunf...
# 652.flac      die readktionellen und auch für den mut solche...
# 653.flac                 der transport wird gewichte im energie
# 655.flac      der punkt auftreten von afrika und seine schla...
# 701.flac      es liegt natürlich in der natur der sache dass...
# 702.flac      mit denen jährlich bis bauliche einzelmassnahm...
# 703.flac         im portfolio des kantons bern sind und gebäude
# 704.flac      im weiteren sind die linien vernutzen spezifis...
# 705.flac      die frankenhöhe rahmenkredit ist gegenüber dem...
# 708.flac      die sehr hohen kosten in den samen des rahmenk...
# 747.flac      definitiv nur in mir ein klares bekenntnis in ...
# 749.flac                             nach ein strakonitzer wird
# ...                                                         ...
# 37310.flac                                seewasser beliebt ist
# 37312.flac    die letzte kompositionen mit lenition letzte k...
# 37313.flac    eine klimadebatte später werden die nachzucht ...
# 37315.flac    die linie finanzieren ist nicht die kompetenz ...
# 37316.flac    nach dem gestrigen tag und der abstimmung noch...
# 37317.flac    als der prototyp werden vielleicht auch den ei...
# 37596.flac    ein wir erfahren dass die kosten der berstende...
# 37598.flac    die studierenden können studienprogramm in zuk...
# 37599.flac    reagiert mit diesem angebot ab auf die gesells...
# 37600.flac    auch die jahresrechnung der schliesst mit eine...
# 37601.flac     die als solche hat sich aus sicht der ph bewährt
# 37602.flac    die damit verbundene finanzautonomie gibt er h...
# 37603.flac    es ist offensichtlich dass für den kanton bern...
# 37683.flac    wie gesagt all die antwort auf die fragen wäre...
# 37684.flac    die sicherheit der bevölkerung wirklich durch ...
# 37686.flac    im übrigen ist beantwortung der motion durch r...
# 37750.flac    wer das ganz natürliche familie umfeld auf der...
# 37751.flac    es bieten werden im besonderen der bewegung un...
# 37752.flac                            die grosse aber in diesem
# 37753.flac    in selbstverantwortung ist ein grosses gut und...
# 37824.flac    da sich der regierungsrat die aufgaben grundsä...
# 37829.flac    so soll der unterricht in der klassischen tier...
# 37831.flac    wenn bei beauftragen auftragnehmer die gelegen...
# 38001.flac    wir schliessen allgemeine dank an und du frakt...
# 38002.flac    der masterplan versucht das vorgeben punkt und...
# 38003.flac    sanierung und den bedarf werden aktuelle umstä...
# 38348.flac                      die gangunterschiede eingreifen
# 38479.flac    schon als spezialfinanzierungen sowie von und ...
# 38480.flac                ein ist weniger gross als beim kanton
# 38481.flac    ich vereinfache wer genau die rechtslage in de...
#
#                                                         res_uzh  \
# wav_filename
# 15.flac       für die grosse arbeit im dienste in unserem ka...
# 16.flac       an dieser stelle auch für die gesammelten werk...
# 70.flac                     ich komme zum zweiten vizepräsidium
# 242.flac      wir sind aber froh das der regierungsrat postu...
# 243.flac      das betreuungsverhältnis bei den tagesschulen ...
# 244.flac      ziel ist unseres erachtens auch noch potenzial...
# 245.flac      die erkenntnisse hat sicher für die ganze schw...
# 246.flac      der kanton an den kosten der schulergänzende b...
# 247.flac      zum nächsten postulat kindergärten einheitlich...
# 248.flac      wir sind ebenfalls der meinung das eine klasse...
# 258.flac         ich möchte zuerst einmal ein kompliment machen
# 259.flac               vor uns der regierungsrat bekanntgemacht
# 286.flac      die bdp fraktion bedauern natürlich ist der ka...
# 287.flac      die bdp unterstützt somit mit einem branche au...
# 316.flac      der zeitpunkt sind uns durchaus richtig und wi...
# 317.flac            die bdp unterstützt diese motion einstimmig
# 471.flac                         beim tram erlebt weltweit eine
# 472.flac      ich zitiere wörtlich aus dem protokoll der deb...
# 476.flac      wer von münsingen an dritte strasse geht auch ...
# 652.flac      wir hatten brava baudirektion für den mut holz...
# 653.flac           nebst transporte gewichtet in minergie p eco
# 655.flac      alle punkte von nachteil halbfabrikaten und so...
# 701.flac      es liegt in der natur der sache durchschnittli...
# 702.flac      mit diesem kredit werden jährlich tausende hun...
# 703.flac              im portfolio vom kanton bern rund gebäude
# 704.flac      im weiteren sinne limiten für benutzer spezifi...
# 705.flac      allerdings franken erhöhen dieser rahmenkredit...
# 708.flac      abschliessend und sehr hohe kosten disziplin w...
# 747.flac      definitiv nur ein däumchen wollen wir ein klar...
# 749.flac      es ist nicht einfach eine stallneubaus lieber ...
# ...                                                         ...
# 37310.flac                bereits wieder etwas sehr beliebt ist
# 37312.flac    die letzten positionen mehr zu lesen in der mo...
# 37313.flac    eine klimadebatte später werden die nachtzüge ...
# 37315.flac    eine neue linie zu finanzieren ist nicht in de...
# 37316.flac    nach dem gestrigen tag und der abstimmung noch...
# 37317.flac    also der prototyp werden vielleicht auch dort ...
# 37596.flac    leider haben wir erfahren die kosten der ph be...
# 37598.flac    die studierenden studienprogramm in zukunft vi...
# 37599.flac    die reagiert mit dem angebot auf die gesellsch...
# 37600.flac    auch diese jahresrechnung anschliessen mit ein...
# 37601.flac         zudem soll es hat sich aus sicht der bewährt
# 37602.flac    die damit verbundene finanzen autonomie der ho...
# 37603.flac    es ist offensichtlich das für den kanton bern ...
# 37683.flac    wie gesagt alle antworten auf ihre fragen zu g...
# 37684.flac    die sicherheit der bevölkerung wirklich durch ...
# 37686.flac    im übrigen ist beantwortung der motion durch d...
# 37750.flac    wer dies ganz natürliche familie umfeld auf le...
# 37751.flac    dennoch fertig werden im besonderen durch bewe...
# 37752.flac          es besteht ein grosses aber in diesem thema
# 37753.flac    zweitens selbstverantwortung ist ein zu grosse...
# 37824.flac    dass sich der regierungsrat diesen aufgaben gr...
# 37829.flac    genauso sollte der unterricht in der klassisch...
# 37831.flac    wenn bei zeitung beauftragt gerber auftrag neh...
# 38001.flac    wir schliessen uns im allgemeinen dank an die ...
# 38002.flac    der masterplan versucht der vorgeschlagenen pu...
# 38003.flac    nicht zuletzt sanierungs und modernisierung be...
# 38348.flac    kunst ist begangen unter dem regierungsrat neu...
# 38479.flac    ich vermisse spezialfinanzierung sowie vous un...
# 38480.flac         verschuldung weniger grosses als beim kanton
# 38481.flac    schliesslich vereinfachen es wäre genau diesel...
#
#                                                        res_zhaw  res_fhnw_wer  \
# wav_filename
# 15.flac         für die grosse arbeit im dienst unseres kantons         40.00
# 16.flac       nach sind an dieser stelle auch für die gesamm...         38.46
# 70.flac                     ich komme zum zweiten vizepräsidium          0.00
# 242.flac      sind aber froh dass der regierungsrat die post...         36.36
# 243.flac      die betreuungsverhältnis der tagesschulen betr...         66.67
# 244.flac      hier ist unser erachten auch ein anpassungseifers         33.33
# 245.flac      diese erkenntnisse hat sicher für die ganze sc...         11.11
# 246.flac      der ertrag den kosten der schulergänzenden bet...         45.45
# 247.flac      zum nächsten postulat kindergärten einheitlich...         40.00
# 248.flac      wir sind ebenfalls der meinung dass eine kasse...         11.11
# 258.flac      ich möchte zuerst einmal der fdp ein komplimen...         50.00
# 259.flac                   der vor der er regierungsrat bekannt         80.00
# 286.flac      die bdp fraktion bedauert es natürlich dass de...         35.29
# 287.flac      sie unterstützt somit mit einem grannen endes ...         66.67
# 316.flac      der zeitpunkt sind uns durchaus richtig und wi...         33.33
# 317.flac            die bdp unterstützt diese motion einstimmig          0.00
# 471.flac      das tram erlebt heute fast weltweit eine römische         12.50
# 472.flac      ich zitiere hier wörtlich aus dem protokoll de...         54.55
# 476.flac      die eier von münsingen an dritte strasse g sch...         50.00
# 652.flac      die raveline baudirektion um den mut diese hol...         31.82
# 653.flac             transport wird gerichtet im minergie p eco         62.50
# 655.flac      in punkt vier ein auf von non teile halbfabrik...         56.00
# 701.flac      es liegt in der natur der sache dass die durch...         11.76
# 702.flac      mit diesem kredit werden jährlich achthundert ...          6.67
# 703.flac      im portfolio des kantons bern sind rund zweita...         40.00
# 704.flac      im weiteren sind die limite für benutzer spezi...         18.75
# 705.flac      der rahmenkredit ist gegenüber dem letzten rah...         25.00
# 708.flac      die eine sehr hohe kostendisziplin wenn es um ...         52.94
# 747.flac      definitiv nur ein leuchttürme wollen wir ein k...         25.00
# 749.flac      dieses nicht einfach ein staubauwerken baumann...         42.86
# ...                                                         ...           ...
# 37310.flac           schon wieder etwas das sehr be beliebt ist         37.50
# 37312.flac    die letzten kompositionen mit lesen in in der ...         53.33
# 37313.flac    und jetzt eine klimadebatte später werden die ...          8.33
# 37315.flac    diese linien finanzieren ist nicht eine kompet...         27.27
# 37316.flac    die nach dem gestrigen tag und der abstimmung ...         38.46
# 37317.flac    so der prototyp werden vielleicht auch zu stel...         52.94
# 37596.flac    leider haben wir erfahren dass die kosten der ...         28.57
# 37598.flac    die studierenden können das studienprogramm in...          8.33
# 37599.flac    die bh reagiert mit diesem angebot ab zweitaus...          7.69
# 37600.flac    auch die jahresrechnung zweitausendachtzehn de...         25.00
# 37601.flac    das dem solches hat sich aus sicht der ph bewährt         33.33
# 37602.flac    die damit verbundene finanzautonomie gibt der ...          0.00
# 37603.flac    es ist offensichtlich dass für den kanton bern...         11.76
# 37683.flac    wie gesagt all die antwort auf seine fragen wä...          7.69
# 37684.flac    die sicherheit der bevölkerung wirklich durch ...         40.00
# 37686.flac    im übrigen ist die beantwortung der motion dur...         22.73
# 37750.flac    wer das ganz natürliche familienumfeld auf das...         62.50
# 37751.flac    die fertigkeiten werden insbesondere durch bew...         34.62
# 37752.flac             es gibt ein grosses aber zu diesem thema         22.22
# 37753.flac    und selbstverantwortung ist ein zu grosses gut...         38.10
# 37824.flac    die dass sich der regierungsrat diesen aufgabe...         10.53
# 37829.flac    also sollte er unterricht in den klassenzimmer...         36.84
# 37831.flac    wenn beide zeitig beauftragt geber und auftrag...         27.78
# 38001.flac    wir schliessen uns ein allgemeinen dank an und...          0.00
# 38002.flac    der masterplan versucht den vorgegebenen eckpu...          0.00
# 38003.flac    die sanierungs und modernes bedarf werden aktu...         32.00
# 38348.flac    eine fauter dem regierungsrat neuhaus weiterge...        123.08
# 38479.flac    das als spezialfinanzierung sowie vor und vorf...         16.67
# 38480.flac    die verschuldung ist weniger gross als beim ka...          0.00
# 38481.flac    wesentlich vereinfachen es wäre genau gleiche ...         40.00
#
#               length_ratio_fhnw  res_ude_wer  length_ratio_ude  res_uzh_wer  \
# wav_filename
# 15.flac                0.758065        50.00          0.629032        60.00
# 16.flac                0.902439        46.15          0.670732        30.77
# 70.flac                1.000000         0.00          1.000000         0.00
# 242.flac               0.914286        54.55          0.828571        45.45
# 243.flac               1.023810        75.00          0.845238        41.67
# 244.flac               1.178571        83.33          0.392857        66.67
# 245.flac               0.933333        22.22          0.866667        33.33
# 246.flac               1.090909        63.64          0.902597        50.00
# 247.flac               1.486486        50.00          1.108108        50.00
# 248.flac               1.000000        44.44          0.909774        22.22
# 258.flac               1.170213        87.50          0.595745        50.00
# 259.flac               0.880952        80.00          0.595238        80.00
# 286.flac               1.088496        58.82          0.610619        29.41
# 287.flac               0.737226        76.19          0.759124        61.90
# 316.flac               0.975155        62.50          0.732919        33.33
# 317.flac               1.000000        66.67          0.674419         0.00
# 471.flac               0.923077        75.00          0.423077        50.00
# 472.flac               0.748744        87.88          0.447236        60.61
# 476.flac               0.888889        78.57          0.822222        50.00
# 652.flac               0.972028        63.64          0.566434        45.45
# 653.flac               1.065217        62.50          0.826087        50.00
# 655.flac               0.872832        80.00          0.520231        60.00
# 701.flac               0.825000         5.88          0.941667        23.53
# 702.flac               0.992188        33.33          0.812500        33.33
# 703.flac               0.901639        40.00          0.754098        50.00
# 704.flac               0.894231        56.25          0.769231        56.25
# 705.flac               1.058252        68.75          0.932039        62.50
# 708.flac               0.989899        82.35          0.555556        52.94
# 747.flac               0.982906        43.75          0.811966        31.25
# 749.flac               1.034483        85.71          0.298851        50.00
# ...                         ...          ...               ...          ...
# 37310.flac             0.951220        75.00          0.512195        50.00
# 37312.flac             1.337209        86.67          0.848837        66.67
# 37313.flac             1.051948        33.33          0.805195         8.33
# 37315.flac             0.953846        63.64          0.923077        27.27
# 37316.flac             1.037037        30.77          0.728395        46.15
# 37317.flac             1.087379        52.94          0.912621        52.94
# 37596.flac             0.987179        47.62          0.717949        23.81
# 37598.flac             0.948454        25.00          0.896907        16.67
# 37599.flac             0.941176        38.46          0.717647        38.46
# 37600.flac             0.901099        50.00          0.703297        56.25
# 37601.flac             0.666667        33.33          0.695652        50.00
# 37602.flac             1.000000        27.27          0.881720        27.27
# 37603.flac             0.950495        29.41          0.841584        17.65
# 37683.flac             0.934783        30.77          0.934783        38.46
# 37684.flac             0.833333        50.00          0.958333        50.00
# 37686.flac             0.973510        45.45          0.874172        36.36
# 37750.flac             0.888889        75.00          0.655556        43.75
# 37751.flac             1.005128        57.69          0.830769        34.62
# 37752.flac             0.833333        77.78          0.520833        33.33
# 37753.flac             0.958621        42.86          0.806897        42.86
# 37824.flac             0.954545        36.84          0.803030         5.26
# 37829.flac             0.987013        63.16          0.857143        36.84
# 37831.flac             0.917808        44.44          0.739726        88.89
# 38001.flac             1.000000        47.06          0.811475        29.41
# 38002.flac             1.000000        29.41          0.901515        29.41
# 38003.flac             0.927835        44.00          0.726804        40.00
# 38348.flac             1.421053       100.00          0.326316       100.00
# 38479.flac             0.910256        38.89          0.993590        33.33
# 38480.flac             1.000000        25.00          0.740000        37.50
# 38481.flac             1.205882        80.00          0.764706        48.00
#
#               length_ratio_uzh  res_zhaw_wer  length_ratio_zhaw
# wav_filename
# 15.flac               0.806452         40.00           0.758065
# 16.flac               0.719512         30.77           0.926829
# 70.flac               1.000000          0.00           1.000000
# 242.flac              0.814286         45.45           0.842857
# 243.flac              1.095238         75.00           1.250000
# 244.flac              1.000000         83.33           0.875000
# 245.flac              0.933333         22.22           0.966667
# 246.flac              0.980519         45.45           0.987013
# 247.flac              1.418919         40.00           1.486486
# 248.flac              0.924812         27.78           0.969925
# 258.flac              0.978723         37.50           1.148936
# 259.flac              0.952381        100.00           0.857143
# 286.flac              0.982301         23.53           1.000000
# 287.flac              0.948905         66.67           0.861314
# 316.flac              0.962733         37.50           0.863354
# 317.flac              1.000000          0.00           1.000000
# 471.flac              0.576923         12.50           0.942308
# 472.flac              0.648241         57.58           0.708543
# 476.flac              1.100000         57.14           1.044444
# 652.flac              0.832168         40.91           0.909091
# 653.flac              0.956522         50.00           0.913043
# 655.flac              0.780347         64.00           0.768786
# 701.flac              0.783333          5.88           0.916667
# 702.flac              1.039062         26.67           1.203125
# 703.flac              0.672131         30.00           1.147541
# 704.flac              1.028846         62.50           1.086538
# 705.flac              1.271845         37.50           1.106796
# 708.flac              0.989899         41.18           0.777778
# 747.flac              1.025641         31.25           1.051282
# 749.flac              1.000000         50.00           0.931034
# ...                        ...           ...                ...
# 37310.flac            0.902439         50.00           1.024390
# 37312.flac            1.174419         40.00           1.139535
# 37313.flac            0.922078         25.00           0.987013
# 37315.flac            1.123077         36.36           0.938462
# 37316.flac            0.925926         46.15           0.975309
# 37317.flac            0.922330         58.82           1.009709
# 37596.flac            0.980769         19.05           0.974359
# 37598.flac            0.886598          8.33           1.041237
# 37599.flac            0.776471         23.08           1.176471
# 37600.flac            0.912088         50.00           1.230769
# 37601.flac            0.637681         25.00           0.710145
# 37602.flac            0.989247          0.00           1.000000
# 37603.flac            0.910891          5.88           0.950495
# 37683.flac            1.065217         38.46           0.891304
# 37684.flac            0.972222         50.00           0.958333
# 37686.flac            0.947020         27.27           0.973510
# 37750.flac            0.844444         68.75           0.855556
# 37751.flac            0.948718         23.08           0.938462
# 37752.flac            0.895833         22.22           0.833333
# 37753.flac            0.820690         33.33           0.827586
# 37824.flac            0.962121         15.79           1.030303
# 37829.flac            0.954545         31.58           0.941558
# 37831.flac            1.089041         44.44           0.904110
# 38001.flac            0.942623         11.76           0.991803
# 38002.flac            0.984848         11.76           0.984848
# 38003.flac            0.953608         36.00           0.876289
# 38348.flac            1.410526        100.00           1.147368
# 38479.flac            1.044872         27.78           1.006410
# 38480.flac            0.880000          0.00           1.000000
# 38481.flac            1.088235         52.00           1.058824
#
# [1006 rows x 13 columns]

# %% [markdown]
# # Section 2: Analysis

# %% [markdown]
# This section is dedicated for data analysis.

# %% [markdown]
# ### 1. Combined Results

# %%
tmp = pd.concat([deepspeech_test, jasper_test], axis=1)
tmp.loc[:,~tmp.columns.duplicated()]
# Out:
# c:\users\aashish agarwal\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                                      src  \
# 10090  aber ich habe etwas mühe für die bdp zu sprech...
# 10091  wir unterstützen die motion sie geht in die ri...
# 10092  die antwort des regierungsrats ist eben leider...
# 10093  es geht nicht um eine doppelte bestrafung der ...
# 10094  der taxifahrer der vielleicht einmal zu schnel...
# 10095  der taxifahrer wird dreimal bestraft und dies ...
# 10096  deshalb muss diese kehrtwende kommen und wir k...
# 10097  sie wissen ja welche landessprache die taxifah...
# 10098  diese leute mit entsprechendem migrationshinte...
# 10221       unsere fraktion schliesst sich der motion an
# 10222  denn es handelt sich nur um eine richtlinienmo...
# 10223       auch uns geht es darum ein zeichen zu setzen
# 10230          die edu fraktion unterstützt diese motion
# 10231                         wir sind gegen besetzungen
# 10232      jedoch wollen wir zwischennutzungen anstreben
# 10233              deshalb sagen wir ja zu dieser motion
# 10270  berücksichtigung öffentlicher interessen beim ...
# 10271  aber wir sehen das öffentliche interesse beim ...
# 10272  wir müssen den kanton vertreten oder ist hier ...
# 10273                 ich komme zu den einzelnen punkten
# 10274  beim beabsichtigten verkauf abzuklären ob jema...
# 10275  der verkauf wird ausgeschrieben und die gemein...
# 10276  der gewerbetreibende muss gleich behandelt werden
# 10277  diesen punkt 1 hätten wir als motion trotz uns...
# 10278       als postulat stimmen wir ihm mehrheitlich zu
# 10279  ich ärgere mich noch heute über den verkauf de...
# 10280  ich bin überzeugt dass man einen viel höheren ...
# 10281  wir sind nicht in der situation so etwas tun z...
# 10282  betreffend das vorkaufsrecht sehen wir es glei...
# 10283  ein solches kann gewisse interessenten darin h...
# ...                                                  ...
# 8380   es sind jene welche der kanton die gef und reg...
# 8381   wer entscheidet denn ob die vorläufig aufgenom...
# 8548   hier geht es noch einmal um das wörtchen grund...
# 8712                              es ist härter geworden
# 8713   aber wenn es irgendeinmal etwas schwieriger un...
# 8714   aber wir müssen aufpassen dass nicht der unter...
# 885    die fin hat sich zur wehr gesetzt und gesagt e...
# 886    dies ist einer der hauptgründe für dieses problem
# 8940   die edu fraktion ist sich bewusst dass das gel...
# 8941   wir stimmen diesem kredit zu und lehnen den rü...
# 9014   wir sind aber froh um die präzisierung denn wi...
# 9015   aber die pragmatische lösung so wie sie jetzt ...
# 9188   die exposition im jugendalter im strassenverke...
# 9189   auch die unfallstatistik spricht klar für dies...
# 9190   es ist wichtig dass alle schülerinnen und schü...
# 9191   der abbruch nach der sechsten klasse ist eine ...
# 9298   mich würde zudem interessieren was grossrat wü...
# 9364   damit werden unbewilligte demonstrationen de f...
# 9412     wer schäden verursacht muss auch dafür bezahlen
# 9445   man hat sogar eine platzkundgebung gemacht wei...
# 9522   andernfalls schiesst das ganze thema der kompe...
# 9523   weil er genau weiss dass man am wochenende und...
# 9987   das ziel ist es einen bestimmten typus von asy...
# 9988   ich denke an all die jungen pseudo asylantrags...
# 9989   das anliegen ist eine negative attraktivitätss...
# 9990   sie will den vorstoss annehmen und auch gleich...
# 9991                das geht mir jedoch etwas zu schnell
# 9992   mein antrag lautet auf nichtabschreibung des v...
# 9993               es handelt sich um die gängige praxis
# 9994   selbst wenn man diese motion annehmen und absc...
#
#                                                   res_dp    wer_dp  \
# 10090        ein bis er die bdp zu sprechen es gleich in  0.705882
# 10091  wir unterstützen die motion unterstützen die m...  0.500000
# 10092               die antwort des rates die leider als  0.500000
# 10093  ich eine doppelte bestrafen der taxifahrer ein...  0.714286
# 10094  der taxifahrer der eichel gefahr gibt den bus ...  0.666667
# 10095  der taxifahrer wird dreimal bestraft und das i...  0.230769
# 10096  aus dieser wenn und kommen und wir können hier...  0.571429
# 10097  in welcher landessprachen die taxifahrer haben...  0.875000
# 10098  leute mit diesem migrationshintergrund sollte ...  0.250000
# 10221                             in einer motion an ein  0.857143
# 10222  nur ein richtlinie motion und in uns kontenfüh...  0.695652
# 10223                        uns geht es um ein zeichen   0.444444
# 10230          die edu fraktion unterstützt diese motion  0.000000
# 10231                         wir sind gegen besetzungen  0.000000
# 10232            in den wir zwischen nutzungen anstreben  0.800000
# 10233                            sagen wir ja zur motion  0.428571
# 10270  berücksichtigung öffentlicher interessen beim ...  0.500000
# 10271          aber wie sehen die öffentliche mit seinen  0.625000
# 10272  in der wir müssten kanton bern oder ist irgend...  0.769231
# 10273                           zu den einzelnen punkten  0.333333
# 10274  bei beabsichtigen verkauf abklären ob jemand i...  0.352941
# 10275  die ausgeschriebene kannte und melden wie der ...  0.714286
# 10276                  das ausmass gleich behandelt wird  0.666667
# 10277  in den hatten wir als motion go abgelehnt trat...  0.833333
# 10278                es hat ulmen wir im mehrheitlich zu  0.571429
# 10279  die noch über den verkauften vier felder der o...  0.500000
# 10280          ich bin überzeugt man hat ein viel lösen   0.666667
# 10281    es sind nicht in der situation so tun zu können  0.181818
# 10282              wegen des vorhauses wie regierungsrat  0.800000
# 10283  das kann gewisse in der senten hen ein artgere...  0.750000
# ...                                                  ...       ...
# 8380   die der kantone und regierungsrat schnee begin...  0.636364
# 8381   es entscheidet über die vorläufig aufgenommen ...  0.400000
# 8548                    wie geht es und es grundsätzlich  0.666667
# 8712                                     es ist hatte er  0.500000
# 8713   aber wenn irgendein nach ein schwieriger wirts...  0.703704
# 8714   aber wir müssen aufpassen dass nicht der unter...  0.333333
# 885    er hat man sich durchgesetzt der sich zur wehr...  0.857143
# 886    es ist einer der hauptgründe weshalb es zu die...  0.625000
# 8940   in der edu fraktion ist uns bewusst dass er da...  0.666667
# 8941   in diesem kredit und lehen der rückweisung ant...  0.700000
# 9014   der frau die er in ungerader dem sogenannten d...  0.947368
# 9015          die nische lösung sowie einen unterstützen  0.785714
# 9188   die exposition in jugend alter im strassenverk...  0.333333
# 9189   die statistik spricht klar für die art von prä...  0.300000
# 9190   es ist wichtig dass alle schülerinnen und schü...  0.217391
# 9191   der abbruch nach der s klasse ist es verpasst ...  0.476190
# 9298   wir mischen wir interessieren was in der präsi...  0.615385
# 9364   er will die demonstrationen de fato für unmöglich  0.857143
# 9412                 wer verursacht muss auch der zahlen  0.428571
# 9445   da sämtliche auflagen tensoren platz unter ver...  1.000000
# 9522   es bildete reihenweise damit als man ein solch...  1.333333
# 9523               diese woche am frieden ist man fragt   0.923077
# 9987   in bestimmten typus bestimmten typus asylbewer...  0.764706
# 9988   in den ist die junge asyl zusteller aus eritre...  0.823529
# 9989   als im sinn einer negativen attraktivitätsstei...  0.833333
# 9990   die weigerung der vorstoss annehmen die aber a...  0.666667
# 9991                           das geht mir aber schnell  0.428571
# 9992                                        der absender  1.000000
# 9993                in der zeit auf dem tiefstand jahren  1.000000
# 9994   in dem die motion minen und abschreiben ändert...  0.846154
#
#        length_ratio_dp                                             res_js  \
# 10090         0.511905             die an bisher die bdp zu sprecherinnen
# 10091         1.180328  wir unterstützen die motion unterstützen diese...
# 10092         0.679245  die antwort des regierungsrates ist eben leide...
# 10093         0.593407  es geht nicht um eine doppelte bestrafung der ...
# 10094         0.692308  der taxifahrer der demnach zu schnell gefahren...
# 10095         0.936842  der taxifahrer mit dreimal bestraft und ist un...
# 10096         0.956044  deshalb muss diese kehrwendung kommen und wir ...
# 10097         0.862069  wie sie ja welche landessprache die taxifahrer...
# 10098         0.848485  leute mit diesen migrationshintergrund sollte ...
# 10221         0.500000                die dertsch liess sich einer motion
# 10222         0.614815  er nur eine richtlinienmotion und wir können u...
# 10223         0.613636       auch uns geht es darum ein zeichen zu setzen
# 10230         1.000000          die edu fraktion unterstützt diese motion
# 10231         1.000000                         wir sind gegen besetzungen
# 10232         0.866667            doch wollen zwischennutzungen anstreben
# 10233         0.621622              deshalb sagen wir ja zu dieser motion
# 10270         0.979381  die berücksichtigung öffentlicher interessen e...
# 10271         0.745455  aber wir sehen die öffentlichen interesse beim...
# 10272         0.933333  wir müssen den kanton vertreten oder in eine b...
# 10273         0.705882                      dann zu den einzelnen punkten
# 10274         0.975000  bei dem absicht igen verkauf abklärung ob jema...
# 10275         0.672515  es wird ausgeschrieben sie kann interessieren ...
# 10276         0.673469                        die gleich behandelt werden
# 10277         0.939759  wer die ziffer eins dann hätten wir als motion...
# 10278         0.795455        das postulat stimmen wir im mehrheitlich zu
# 10279         0.970588  natürlich ärgern sich noch heute über den verk...
# 10280         0.561644      ich bin überzeugt man hätte viel lösen können
# 10281         0.870370  wir sind nicht in der situation sowas tun zu k...
# 10282         0.528571  wegen dem vorkaufs es sollen wir es wie der re...
# 10283         0.761364  das kann gewisse interessenten hämmern einen m...
# ...                ...                                                ...
# 8380          0.676056  die die der kanton die gef und der regierungsr...
# 8381          0.962963  die leiter entscheidet darüber ob die vorläufi...
# 8548          0.592593    hier geht es um das wort grundsätzlich verraten
# 8712          0.681818                               es ist hätter worden
# 8713          0.616766  aber wenn irgendwann schwieriger die wirtschaf...
# 8714          0.791209  aber wir müssen aufpassen dass nicht der unter...
# 885           1.131579  in der bve sich durchgesetzt merz sich in zur ...
# 886           1.163265  das ist einer der hauptgründe weshalb es zu di...
# 8940          0.650000  in der edu fraktion ist uns bewusst dass für j...
# 8941          0.800000  ich stimme diesem kredit zu und lehnen den rüc...
# 9014          0.508065  es ist sicher froh um die präzisierung nicht f...
# 9015          0.461538  die pragmatische lösung wie sie präzisiert wur...
# 9188          1.011111  die exposition im jugendalter dem strassenverk...
# 9189          0.803030  die enentat tistik spricht hier klar für diese...
# 9190          0.881081  es ist wichtig dass alle schülerinnen und schü...
# 9191          0.955224  der abbruch nach der sechsten klasse ist eine ...
# 9298          0.711340  wir werden schon interessieren was sie der prä...
# 9364          0.765625  der unbewilligte demonstrationen de facto veru...
# 9412          0.744681      wäre eben verursacht muss auch dafür bezahlen
# 9445          0.801980  es sich ein sämtliche auflagen wenn sogar eine...
# 9522          1.522727  die eu braucht noch legitimierte ausgebildete ...
# 9523          0.500000  genau weiss am wochenende am freitag abend war...
# 9987          0.772277  eine bestimmte tipus sen bestimmten typus asyl...
# 9988          0.930000  ein denke dass all die jungen zwei asylstätten...
# 9989          0.945455  als im sinne einer negativen attraktivitätsste...
# 9990          0.965517  die regierung will der vorstoss annehmen wie a...
# 9991          0.694444                          das geht mir aber schnell
# 9992          0.218182     der antrag wird nichtabschreibung des vorstoss
# 9993          0.972973  lesen in der zeitung auf dem tiefsten stand si...
# 9994          0.869048  sonst wenn man diese motion annehmen und absch...
#
#          wer_js  length_ratio_js
# 10090  0.823529         0.452381
# 10091  0.400000         1.327869
# 10092  0.125000         1.018868
# 10093  0.142857         1.000000
# 10094  0.500000         0.800905
# 10095  0.230769         0.894737
# 10096  0.142857         0.967033
# 10097  0.375000         0.896552
# 10098  0.333333         0.808081
# 10221  0.714286         0.795455
# 10222  0.695652         0.740741
# 10223  0.000000         1.000000
# 10230  0.000000         1.000000
# 10231  0.000000         1.000000
# 10232  0.400000         0.866667
# 10233  0.000000         1.000000
# 10270  0.250000         1.010309
# 10271  0.250000         1.018182
# 10272  0.384615         0.855556
# 10273  0.333333         0.852941
# 10274  0.529412         0.975000
# 10275  0.714286         0.859649
# 10276  0.500000         0.551020
# 10277  0.833333         1.156627
# 10278  0.285714         0.977273
# 10279  0.277778         1.068627
# 10280  0.500000         0.616438
# 10281  0.181818         0.944444
# 10282  0.600000         0.814286
# 10283  0.416667         0.875000
# ...         ...              ...
# 8380   0.409091         0.908451
# 8381   0.266667         1.083333
# 8548   0.444444         0.870370
# 8712   0.500000         0.909091
# 8713   0.666667         0.874251
# 8714   0.066667         1.021978
# 885    0.785714         1.144737
# 886    0.625000         1.183673
# 8940   0.600000         0.975000
# 8941   0.200000         0.984615
# 9014   0.631579         0.741935
# 9015   0.357143         0.791209
# 9188   0.250000         1.011111
# 9189   0.400000         0.984848
# 9190   0.130435         0.983784
# 9191   0.238095         1.014925
# 9298   0.615385         0.649485
# 9364   0.285714         0.859375
# 9412   0.285714         0.957447
# 9445   1.000000         0.900990
# 9522   1.916667         2.295455
# 9523   0.692308         0.770270
# 9987   0.705882         0.801980
# 9988   0.647059         1.050000
# 9989   0.833333         0.963636
# 9990   0.666667         1.051724
# 9991   0.428571         0.694444
# 9992   0.571429         0.836364
# 9993   1.571429         1.648649
# 9994   0.615385         1.047619
#
# [1801 rows x 7 columns]

# %% [markdown]
# ### 1. Length Graph

# %% [markdown]
# **a. Train**

# %%
ax = sns.kdeplot(deepspeech_train['length_ratio_dp'], shade=True)
sns.kdeplot(jasper_train['length_ratio_js'], shade=True)

sns.set_style("whitegrid")
ax.set(xlabel='Length Ratio', ylabel='Density')

print('Blue: DeepSpeech')
print('Orange: Jasper')
# Out:
# Blue: DeepSpeech
# Orange: Jasper

# %% [markdown]
# **b. Dev**

# %%
ax = sns.kdeplot(deepspeech_dev['length_ratio_dp'], shade=True)
sns.kdeplot(jasper_dev['length_ratio_js'], shade=True)

sns.set_style("whitegrid")
ax.set(xlabel='Length Ratio', ylabel='Density')

print('Blue: DeepSpeech')
print('Orange: Jasper')
# Out:
# Blue: DeepSpeech
# Orange: Jasper

# %% [markdown]
# **c. Test**

# %%
ax = sns.kdeplot(deepspeech_test['length_ratio_dp'], shade=True)
sns.kdeplot(jasper_test['length_ratio_js'], shade=True)
sns.kdeplot(kaldi_test['length_ratio_kd'], shade=True)

sns.set_style("whitegrid")
ax.set(xlabel='Length Ratio', ylabel='Density')

print('Blue: DeepSpeech')
print('Orange: Jasper')
print('Green: Kaldi')
# Out:
# Blue: DeepSpeech
# Orange: Jasper
# Green: Kaldi

# %% [markdown]
# **d. Private Test**

# %%
ax = sns.kdeplot(combined_test_pri['length_ratio_fhnw'], shade=True)
sns.kdeplot(combined_test_pri['length_ratio_ude'], shade=True)
sns.kdeplot(combined_test_pri['length_ratio_uzh'], shade=True)
sns.kdeplot(combined_test_pri['length_ratio_zhaw'], shade=True)

sns.set_style("whitegrid")
ax.set(xlabel='Length Ratio', ylabel='Density')
# Out:
# [Text(0, 0.5, 'Density'), Text(0.5, 0, 'Length Ratio')]

# %% [markdown]
# **WER Train**

# %%
deepspeech_train_no_issue = deepspeech_train[deepspeech_train['length_ratio_dp'] > 0.75]
jasper_train_no_issue = jasper_train[jasper_train['length_ratio_js'] > 0.75]

# %%
#deepspeech
issue_dp = round(deepspeech_train['wer_dp'].mean()*100,2)
no_issue_dp = round(deepspeech_train_no_issue['wer_dp'].mean()*100,2)

#jasper
issue_jp = round(jasper_train['wer_js'].mean()*100,2)
no_issue_jp = round(jasper_train_no_issue['wer_js'].mean()*100,2)

# %%
data = [["Issue", issue_dp, issue_jp], ["No Issue", no_issue_dp, no_issue_jp]]
df = pd.DataFrame(data, columns=["Index", "Mozilla", "Jasper"])
df.set_index("Index")
# Out:
#           Mozilla  Jasper
# Index
# Issue       53.82   15.88
# No Issue    46.26   13.27

# %% [markdown]
# **WER Dev**

# %%
deepspeech_dev_no_issue = deepspeech_dev[deepspeech_dev['length_ratio_dp'] > 0.75]
jasper_dev_no_issue = jasper_dev[jasper_dev['length_ratio_js'] > 0.75]

# %%
#deepspeech
issue_dp = round(deepspeech_dev['wer_dp'].mean()*100,2)
no_issue_dp = round(deepspeech_dev_no_issue['wer_dp'].mean()*100,2)

#jasper
issue_jp = round(jasper_dev['wer_js'].mean()*100,2)
no_issue_jp = round(jasper_dev_no_issue['wer_js'].mean()*100,2)

# %%
data = [["Issue", issue_dp, issue_jp], ["No Issue", no_issue_dp, no_issue_jp]]
df = pd.DataFrame(data, columns=["Index", "Mozilla", "Jasper"])
df.set_index("Index")
# Out:
#           Mozilla  Jasper
# Index
# Issue       57.86   41.30
# No Issue    51.00   39.66

# %% [markdown]
# **WER Test**

# %%
deepspeech_test_no_issue = deepspeech_test[deepspeech_test['length_ratio_dp'] > 0.75]
jasper_test_no_issue = jasper_test[jasper_test['length_ratio_js'] > 0.75]
kaldi_test_no_issue = kaldi_test[kaldi_test['length_ratio_kd'] > 0.75]

# %%
#deepspeech
issue_dp = round(deepspeech_test['wer_dp'].mean()*100,2)
no_issue_dp = round(deepspeech_test_no_issue['wer_dp'].mean()*100,2)

#jasper
issue_jp = round(jasper_test['wer_js'].mean()*100,2)
no_issue_jp = round(jasper_test_no_issue['wer_js'].mean()*100,2)

#kaldi
issue_kd = round(kaldi_test['wer_kd'].mean(),2)
no_issue_kd = round(kaldi_test_no_issue['wer_kd'].mean(),2)

# %%
data = [["Issue", issue_dp, issue_jp, issue_kd], ["No Issue", no_issue_dp, no_issue_jp, no_issue_kd]]
df = pd.DataFrame(data, columns=["Index", "Mozilla", "Jasper", "Kaldi"])
df.set_index("Index")
# Out:
#           Mozilla  Jasper  Kaldi
# Index
# Issue       59.68   44.01  23.74
# No Issue    51.18   41.90  21.25

# %% [markdown]
# **WER Test Private**

# %%
fhnw_no_issue = combined_test_pri[combined_test_pri['length_ratio_fhnw'] > 0.75]
ude_pri_no_issue = combined_test_pri[combined_test_pri['length_ratio_ude'] > 0.75]
uzh_no_issue = combined_test_pri[combined_test_pri['length_ratio_uzh'] > 0.75]
zhaw_pri_no_issue = combined_test_pri[combined_test_pri['length_ratio_zhaw'] > 0.75]

# %%
#fhnw
issue_fhnw = round(combined_test_pri['res_fhnw_wer'].mean(),2)
no_issue_fhnw = round(fhnw_no_issue['res_fhnw_wer'].mean(),2)

#ude
issue_ude = round(combined_test_pri['res_ude_wer'].mean(),2)
no_issue_ude = round(fhnw_no_issue['res_ude_wer'].mean(),2)

#uzh
issue_uzh = round(combined_test_pri['res_uzh_wer'].mean(),2)
no_issue_uzh = round(fhnw_no_issue['res_uzh_wer'].mean(),2)

#zhaw
issue_zhaw = round(combined_test_pri['res_zhaw_wer'].mean(),2)
no_issue_zhaw = round(fhnw_no_issue['res_zhaw_wer'].mean(),2)

# %%
data = [["Issue", issue_fhnw, issue_ude, issue_uzh, issue_zhaw], ["No Issue", no_issue_fhnw, no_issue_ude, no_issue_uzh, no_issue_zhaw]]
df = pd.DataFrame(data, columns=["Index", "FHNW", "UDE", "UZH", "ZHAW"])
df.set_index("Index")
# Out:
#            FHNW    UDE    UZH   ZHAW
# Index
# Issue     36.10  58.87  45.38  40.27
# No Issue  34.87  57.92  44.86  39.40
